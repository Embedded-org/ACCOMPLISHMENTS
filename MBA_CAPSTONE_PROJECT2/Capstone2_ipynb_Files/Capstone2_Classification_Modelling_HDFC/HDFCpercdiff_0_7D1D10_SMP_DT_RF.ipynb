# %%
#Importing the Libraries
import matplotlib. pyplot as plt
import matplotlib
from sklearn.preprocessing import MinMaxScaler
import numpy as np
import pandas as pd
import sklearn
import sklearn.linear_model as lm
from sklearn import preprocessing
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.metrics import roc_curve,auc,recall_score,precision_score,accuracy_score,f1_score
from sklearn.metrics import confusion_matrix,average_precision_score,recall_score
import matplotlib.pyplot as plt
# %matplotlib inline
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
all_data = pd.read_csv("HDFCBANK.csv")
all_data=all_data.drop(['Date','Trades','Deliverable Volume','%Deliverble','Symbol','Series'],axis=1)
all_data.head()
# Out:
#    Prev Close   Open    High    Low   Last   Close    VWAP  Volume  \
# 0      271.75  293.5  293.50  293.5  293.5  293.50  293.50   22744
# 1      293.50  317.0  317.00  297.0  304.0  304.05  303.62  255251
# 2      304.05  290.0  303.90  285.0  295.0  292.80  294.53  269087
# 3      292.80  301.0  314.00  295.0  296.0  296.45  300.14  305916
# 4      296.45  290.0  296.35  281.0  287.1  286.55  288.80  197039
#
#        Turnover
# 0  6.675364e+11
# 1  7.749972e+12
# 2  7.925368e+12
# 3  9.181669e+12
# 4  5.690480e+12

# %%
Close_list = all_data['Close'].tolist()
total=len(Close_list);

# %%
j=0
j=0
D1=[]
D2=[]
D3=[]
D4=[]
D5=[]
D6=[]
D7=[]
D8=[]
D9=[]
D10=[]
D11=[]
D12=[]
DIFF=[]
PERCDIFF=[]
TARGET=[]
for i in range(0,total):
  D1.append(Close_list[j])
  D2.append(Close_list[j+1])
  D3.append(Close_list[j+2])
  D4.append(Close_list[j+3])
  D5.append(Close_list[j+4])
  D6.append(Close_list[j+5])
  D7.append(Close_list[j+6])
  D8.append(Close_list[j+7])
  D9.append(Close_list[j+8])
  D10.append(Close_list[j+9])
  D11.append(Close_list[j+10])
  D12.append(Close_list[j+11])
  diff=Close_list[j+11]-Close_list[j+10]
  DIFF.append(diff)
  percdiff=(diff*100)/Close_list[j+11]
  PERCDIFF.append(percdiff)
  if(percdiff>0.7):
    TARGET.append('pos')
  elif(percdiff<-0.7):
    TARGET.append('neg')
  else:
    TARGET.append('neu')
  j=j+1;
  if(j==total-11):
    break

# %%
df1=pd.DataFrame(D1)
df2=pd.DataFrame(D2)
df3=pd.DataFrame(D3)
df4=pd.DataFrame(D4)
df5=pd.DataFrame(D5)
df6=pd.DataFrame(D6)
df7=pd.DataFrame(D7)
df8=pd.DataFrame(D8)
df9=pd.DataFrame(D9)
df10=pd.DataFrame(D10)
df11=pd.DataFrame(D11)
df12=pd.DataFrame(D12)
df13=pd.DataFrame(DIFF)
df14=pd.DataFrame(PERCDIFF)
df15=pd.DataFrame(TARGET)
df=pd.DataFrame()
df['Close']=all_data['Close']
df['D1']=df1
df['D2']=df2
df['D3']=df3
df['D4']=df4
df['D5']=df5
df['D6']=df6
df['D7']=df7
df['D8']=df8
df['D9']=df9
df['D10']=df10
df['D11']=df11
df['D12']=df12
df['DIFF']=df13
df['PERCDIFF']=df14
df['TARGET']=df15
df.dropna(inplace=True)
df.head(10)
# Out:
#     Close      D1      D2      D3      D4      D5      D6      D7      D8  \
# 0  293.50  293.50  304.05  292.80  296.45  286.55  287.20  283.85  285.60
# 1  304.05  304.05  292.80  296.45  286.55  287.20  283.85  285.60  283.85
# 2  292.80  292.80  296.45  286.55  287.20  283.85  285.60  283.85  286.55
# 3  296.45  296.45  286.55  287.20  283.85  285.60  283.85  286.55  302.20
# 4  286.55  286.55  287.20  283.85  285.60  283.85  286.55  302.20  305.75
# 5  287.20  287.20  283.85  285.60  283.85  286.55  302.20  305.75  305.25
# 6  283.85  283.85  285.60  283.85  286.55  302.20  305.75  305.25  291.35
# 7  285.60  285.60  283.85  286.55  302.20  305.75  305.25  291.35  299.55
# 8  283.85  283.85  286.55  302.20  305.75  305.25  291.35  299.55  293.05
# 9  286.55  286.55  302.20  305.75  305.25  291.35  299.55  293.05  303.15
#
#        D9     D10     D11     D12   DIFF  PERCDIFF TARGET
# 0  283.85  286.55  302.20  305.75   3.55  1.161079    pos
# 1  286.55  302.20  305.75  305.25  -0.50 -0.163800    neu
# 2  302.20  305.75  305.25  291.35 -13.90 -4.770894    neg
# 3  305.75  305.25  291.35  299.55   8.20  2.737439    pos
# 4  305.25  291.35  299.55  293.05  -6.50 -2.218052    neg
# 5  291.35  299.55  293.05  303.15  10.10  3.331684    pos
# 6  299.55  293.05  303.15  316.60  13.45  4.248263    pos
# 7  293.05  303.15  316.60  324.40   7.80  2.404439    pos
# 8  303.15  316.60  324.40  333.50   9.10  2.728636    pos
# 9  316.60  324.40  333.50  350.55  17.05  4.863785    pos

# %%
features = ['D1','D2','D3','D4','D5','D6','D7','D8','D9','D10']
df1=df[features]
df1['TARGET']=df['TARGET']
df1.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#        D1      D2      D3      D4      D5      D6      D7      D8      D9  \
# 0  293.50  304.05  292.80  296.45  286.55  287.20  283.85  285.60  283.85
# 1  304.05  292.80  296.45  286.55  287.20  283.85  285.60  283.85  286.55
# 2  292.80  296.45  286.55  287.20  283.85  285.60  283.85  286.55  302.20
# 3  296.45  286.55  287.20  283.85  285.60  283.85  286.55  302.20  305.75
# 4  286.55  287.20  283.85  285.60  283.85  286.55  302.20  305.75  305.25
#
#       D10 TARGET
# 0  286.55    pos
# 1  302.20    neu
# 2  305.75    neg
# 3  305.25    pos
# 4  291.35    neg

# %%
df0=df
df0['TARGET']= np.where(df0['TARGET']=='pos','1',(np.where(df0['TARGET']=='neg','-1','0')))
df0.head()
df0.groupby('TARGET').size()
# Out:
#     Close      D1      D2      D3      D4      D5      D6      D7      D8  \
# 0  293.50  293.50  304.05  292.80  296.45  286.55  287.20  283.85  285.60
# 1  304.05  304.05  292.80  296.45  286.55  287.20  283.85  285.60  283.85
# 2  292.80  292.80  296.45  286.55  287.20  283.85  285.60  283.85  286.55
# 3  296.45  296.45  286.55  287.20  283.85  285.60  283.85  286.55  302.20
# 4  286.55  286.55  287.20  283.85  285.60  283.85  286.55  302.20  305.75
#
#        D9     D10     D11     D12   DIFF  PERCDIFF TARGET
# 0  283.85  286.55  302.20  305.75   3.55  1.161079      1
# 1  286.55  302.20  305.75  305.25  -0.50 -0.163800      0
# 2  302.20  305.75  305.25  291.35 -13.90 -4.770894     -1
# 3  305.75  305.25  291.35  299.55   8.20  2.737439      1
# 4  305.25  291.35  299.55  293.05  -6.50 -2.218052     -1
# TARGET
# -1    1790
# 0     1883
# 1     1893
# dtype: int64

# %% [markdown]
# #Explore the class distribution

# %%
sns.countplot(df0['TARGET'])
plt.xlabel('TARGET')
plt.title('Number of positive negative and neutral messages')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0.5, 0, 'TARGET')
# Text(0.5, 1.0, 'Number of positive negative and neutral messages')

# %%
#DUMMY CODING USING THE LOOP STRUCTURE
for col in df1.columns:
  if df1[col].dtype=='object':
    df1[col]=pd.Categorical(df1[col]).codes
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
scaler = MinMaxScaler()
feature_transform = scaler.fit_transform(df1[features])
feature_transform= pd.DataFrame(columns=features, data=feature_transform)
feature_transform.head()
# Out:
#          D1        D2        D3        D4        D5        D6        D7  \
# 0  0.003332  0.006974  0.003090  0.004350  0.000932  0.001157  0.000000
# 1  0.006974  0.003090  0.004350  0.000932  0.001157  0.000000  0.000604
# 2  0.003090  0.004350  0.000932  0.001157  0.000000  0.000604  0.000000
# 3  0.004350  0.000932  0.001157  0.000000  0.000604  0.000000  0.000932
# 4  0.000932  0.001157  0.000000  0.000604  0.000000  0.000932  0.006336
#
#          D8        D9       D10
# 0  0.000604  0.000000  0.000000
# 1  0.000000  0.000932  0.005408
# 2  0.000932  0.006336  0.006635
# 3  0.006336  0.007561  0.006463
# 4  0.007561  0.007389  0.001659

# %%
x=feature_transform
x.head()
y=df1['TARGET']
y.head()
# Out:
#          D1        D2        D3        D4        D5        D6        D7  \
# 0  0.003332  0.006974  0.003090  0.004350  0.000932  0.001157  0.000000
# 1  0.006974  0.003090  0.004350  0.000932  0.001157  0.000000  0.000604
# 2  0.003090  0.004350  0.000932  0.001157  0.000000  0.000604  0.000000
# 3  0.004350  0.000932  0.001157  0.000000  0.000604  0.000000  0.000932
# 4  0.000932  0.001157  0.000000  0.000604  0.000000  0.000932  0.006336
#
#          D8        D9       D10
# 0  0.000604  0.000000  0.000000
# 1  0.000000  0.000932  0.005408
# 2  0.000932  0.006336  0.006635
# 3  0.006336  0.007561  0.006463
# 4  0.007561  0.007389  0.001659
# 0    2
# 1    1
# 2    0
# 3    2
# 4    0
# Name: TARGET, dtype: int8

# %%
#create test and train data 70% and 30% split
train_x,test_x,train_y,test_y=train_test_split(x,y,test_size=0.3)
train_x.shape
test_x.shape
train_x.shape
train_y.shape
# Out:
# (3896, 10)
# (1670, 10)
# (3896, 10)
# (3896,)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree
import pydotplus

#CREATE DECISION TREE CLASSIFIER OBJECT
decisiontree1=DecisionTreeClassifier(criterion="gini",random_state=0,max_depth=4,class_weight=None)
#TRAIN MODEL
model=decisiontree1.fit(train_x,train_y)
model
classes=decisiontree1.predict(test_x)
# Out:
# DecisionTreeClassifier(max_depth=4, random_state=0)

# %% [markdown]
# #ACCURACY SCORE-Decision Tree Classifier

# %%
#PRECISION AND RECALL
print("ACCUIRACY SCORE")
print(metrics.accuracy_score(test_y,classes))
# Out:
# ACCUIRACY SCORE
# 0.3341317365269461

# %%
#PRECISION RECALL MATRIX
print("precision/recall Metrics")
print(metrics.classification_report(test_y,classes))
# Out:
# precision/recall Metrics
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       559
#            1       0.33      0.99      0.50       550
#            2       0.42      0.02      0.05       561
#
#     accuracy                           0.33      1670
#    macro avg       0.25      0.34      0.18      1670
# weighted avg       0.25      0.33      0.18      1670
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
#CONFUSION MATRIX
print("CONFUSION MATRIX")
cf=metrics.confusion_matrix(test_y,classes)
lbl1=["Predicted 0","Predicted 1","Predicted 2"]
lbl2=["True 0","True 1","True 2"]
sns.heatmap(cf,annot=True,cmap="Greens",fmt="d",xticklabels=lbl1,yticklabels=lbl2)
plt.show()
# Out:
# CONFUSION MATRIX

# %%
from scipy.stats import randint
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import RandomizedSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn import tree
from sklearn.model_selection import GridSearchCV

# %%
param_dist = {"max_depth": [3, None],
              "max_features": randint(1, 10),
              "min_samples_leaf": randint(1, 10),
              "criterion": ["gini", "entropy"]}

# %%
# Instantiate the RandomizedSearchCV object: tree_cv
tree_cv = RandomizedSearchCV(decisiontree1, param_dist, cv=5)

# %%
# Fit it to the data
tree_cv.fit(train_x,train_y)
# Print the tuned parameters and score
print("Tuned Decision Tree Parameters: {}".format(tree_cv.best_params_))
print("Best score is {}".format(tree_cv.best_score_))
classes=tree_cv.predict(test_x)
# Out:
# RandomizedSearchCV(cv=5,
#                    estimator=DecisionTreeClassifier(max_depth=4,
#                                                     random_state=0),
#                    param_distributions={'criterion': ['gini', 'entropy'],
#                                         'max_depth': [3, None],
#                                         'max_features': <scipy.stats._distn_infrastructure.rv_frozen object at 0x7fc94d326b90>,
#                                         'min_samples_leaf': <scipy.stats._distn_infrastructure.rv_frozen object at 0x7fc94d326410>})
# Tuned Decision Tree Parameters: {'criterion': 'gini', 'max_depth': None, 'max_features': 3, 'min_samples_leaf': 4}
# Best score is 0.3578038905895132

# %% [markdown]
# #ACCURACY SCORE-Decision Tree Classifier using RandomizedSearchCV

# %%
#PRECISION AND RECALL
print("ACCUIRACY SCORE")
print(metrics.accuracy_score(test_y,classes))
# Out:
# ACCUIRACY SCORE
# 0.3383233532934132

# %%
#PRECISION RECALL MATRIX
print("precision/recall Metrics")
print(metrics.classification_report(test_y,classes))
# Out:
# precision/recall Metrics
#               precision    recall  f1-score   support
#
#            0       0.33      0.36      0.34       559
#            1       0.34      0.33      0.33       550
#            2       0.35      0.33      0.34       561
#
#     accuracy                           0.34      1670
#    macro avg       0.34      0.34      0.34      1670
# weighted avg       0.34      0.34      0.34      1670

# %%
#CONFUSION MATRIX
print("CONFUSION MATRIX")
cf=metrics.confusion_matrix(test_y,classes)
lbl1=["Predicted 0","Predicted 1","Predicted 2"]
lbl2=["True 0","True 1","True 2"]
sns.heatmap(cf,annot=True,cmap="Greens",fmt="d",xticklabels=lbl1,yticklabels=lbl2)
plt.show()
# Out:
# CONFUSION MATRIX

# %%
my_max_depth=[20,30,40,50,None]
my_criterion=['gini','entropy']
my_min_samples_split=[2,100,20,50,100]
#BUILDING THE MODEL
mytreeone=DecisionTreeClassifier()
#CROSS VALIDATION TELLS HOW A MODEL PERFORMS ON A DATASET USING MULTIPLE SAMPLES OF TRAIN DATA
grid=GridSearchCV(estimator=mytreeone,cv=3,param_grid=dict(max_depth=my_max_depth,criterion=my_criterion,min_samples_split=my_min_samples_split))
grid.fit(train_x,train_y)
classes=grid.predict(test_x)
# Out:
# GridSearchCV(cv=3, estimator=DecisionTreeClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [20, 30, 40, 50, None],
#                          'min_samples_split': [2, 100, 20, 50, 100]})

# %% [markdown]
# #ACCURACY SCORE-Decision Tree Classifier using GridSearchCV

# %%
#PRECISION AND RECALL
print("ACCUIRACY SCORE")
print(metrics.accuracy_score(test_y,classes))
# Out:
# ACCUIRACY SCORE
# 0.3335329341317365

# %%
#PRECISION RECALL MATRIX
print("precision/recall Metrics")
print(metrics.classification_report(test_y,classes))
# Out:
# precision/recall Metrics
#               precision    recall  f1-score   support
#
#            0       0.35      0.14      0.20       559
#            1       0.32      0.23      0.26       550
#            2       0.33      0.63      0.44       561
#
#     accuracy                           0.33      1670
#    macro avg       0.33      0.33      0.30      1670
# weighted avg       0.33      0.33      0.30      1670

# %%
#CONFUSION MATRIX
print("CONFUSION MATRIX")
cf=metrics.confusion_matrix(test_y,classes)
lbl1=["Predicted 0","Predicted 1","Predicted 2"]
lbl2=["True 0","True 1","True 2"]
sns.heatmap(cf,annot=True,cmap="Greens",fmt="d",xticklabels=lbl1,yticklabels=lbl2)
plt.show()
# Out:
# CONFUSION MATRIX

# %%
n_estimators=[10,500,100,2000]
criterion=['gini','entropy']
min_samples_split=[10,20,30,40,50]
max_depth=[2,3,4,5,None]

# %%
param_grid={'n_estimators':n_estimators,'criterion':criterion,'min_samples_split':min_samples_split,'max_depth':max_depth}
rf=RandomForestClassifier()
rf_g=RandomizedSearchCV(rf,param_grid,cv=5,verbose=2,n_jobs=-1)
rf_g.fit(x,y)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV] END criterion=entropy, max_depth=4, min_samples_split=20, n_estimators=10; total time=   0.1s
# [CV] END criterion=entropy, max_depth=4, min_samples_split=20, n_estimators=10; total time=   0.1s
# [CV] END criterion=entropy, max_depth=4, min_samples_split=20, n_estimators=10; total time=   0.1s
# [CV] END criterion=entropy, max_depth=4, min_samples_split=20, n_estimators=10; total time=   0.2s
# [CV] END criterion=entropy, max_depth=4, min_samples_split=20, n_estimators=10; total time=   0.1s
# [CV] END criterion=gini, max_depth=5, min_samples_split=20, n_estimators=2000; total time=  16.8s
# [CV] END criterion=gini, max_depth=5, min_samples_split=20, n_estimators=2000; total time=  15.5s
# [CV] END criterion=gini, max_depth=5, min_samples_split=20, n_estimators=2000; total time=  15.3s
# [CV] END criterion=gini, max_depth=5, min_samples_split=20, n_estimators=2000; total time=  14.6s
# [CV] END criterion=gini, max_depth=5, min_samples_split=20, n_estimators=2000; total time=  16.1s
# [CV] END criterion=gini, max_depth=None, min_samples_split=10, n_estimators=10; total time=   0.9s
# [CV] END criterion=gini, max_depth=None, min_samples_split=10, n_estimators=10; total time=   0.4s
# [CV] END criterion=gini, max_depth=None, min_samples_split=10, n_estimators=10; total time=   0.2s
# [CV] END criterion=gini, max_depth=None, min_samples_split=10, n_estimators=10; total time=   0.2s
# [CV] END criterion=gini, max_depth=None, min_samples_split=10, n_estimators=10; total time=   0.2s
# [CV] END criterion=entropy, max_depth=4, min_samples_split=50, n_estimators=100; total time=   1.2s
# [CV] END criterion=entropy, max_depth=4, min_samples_split=50, n_estimators=100; total time=   1.2s
# [CV] END criterion=entropy, max_depth=4, min_samples_split=50, n_estimators=100; total time=   1.2s
# [CV] END criterion=entropy, max_depth=4, min_samples_split=50, n_estimators=100; total time=   1.1s
# [CV] END criterion=entropy, max_depth=4, min_samples_split=50, n_estimators=100; total time=   1.1s
# [CV] END criterion=entropy, max_depth=2, min_samples_split=10, n_estimators=500; total time=   3.5s
# [CV] END criterion=entropy, max_depth=2, min_samples_split=10, n_estimators=500; total time=   3.6s
# [CV] END criterion=entropy, max_depth=2, min_samples_split=10, n_estimators=500; total time=   3.6s
# [CV] END criterion=entropy, max_depth=2, min_samples_split=10, n_estimators=500; total time=   3.5s
# [CV] END criterion=entropy, max_depth=2, min_samples_split=10, n_estimators=500; total time=   3.5s
# [CV] END criterion=entropy, max_depth=4, min_samples_split=10, n_estimators=2000; total time=  30.0s
# [CV] END criterion=entropy, max_depth=4, min_samples_split=10, n_estimators=2000; total time=  26.4s
# [CV] END criterion=entropy, max_depth=4, min_samples_split=10, n_estimators=2000; total time=  24.4s
# [CV] END criterion=entropy, max_depth=4, min_samples_split=10, n_estimators=2000; total time=  22.6s
# [CV] END criterion=entropy, max_depth=4, min_samples_split=10, n_estimators=2000; total time=  23.3s
# [CV] END criterion=gini, max_depth=4, min_samples_split=30, n_estimators=500; total time=   3.8s
# [CV] END criterion=gini, max_depth=4, min_samples_split=30, n_estimators=500; total time=   3.4s
# [CV] END criterion=gini, max_depth=4, min_samples_split=30, n_estimators=500; total time=   3.4s
# [CV] END criterion=gini, max_depth=4, min_samples_split=30, n_estimators=500; total time=   3.2s
# [CV] END criterion=gini, max_depth=4, min_samples_split=30, n_estimators=500; total time=   3.2s
# [CV] END criterion=entropy, max_depth=2, min_samples_split=50, n_estimators=10; total time=   0.1s
# [CV] END criterion=entropy, max_depth=2, min_samples_split=50, n_estimators=10; total time=   0.1s
# [CV] END criterion=entropy, max_depth=2, min_samples_split=50, n_estimators=10; total time=   0.1s
# [CV] END criterion=entropy, max_depth=2, min_samples_split=50, n_estimators=10; total time=   0.1s
# [CV] END criterion=entropy, max_depth=2, min_samples_split=50, n_estimators=10; total time=   0.1s
# [CV] END criterion=entropy, max_depth=5, min_samples_split=30, n_estimators=2000; total time=  28.8s
# [CV] END criterion=entropy, max_depth=5, min_samples_split=30, n_estimators=2000; total time=  29.3s
# [CV] END criterion=entropy, max_depth=5, min_samples_split=30, n_estimators=2000; total time=  27.8s
# [CV] END criterion=entropy, max_depth=5, min_samples_split=30, n_estimators=2000; total time=  26.5s
# [CV] END criterion=entropy, max_depth=5, min_samples_split=30, n_estimators=2000; total time=  27.3s
# [CV] END criterion=entropy, max_depth=2, min_samples_split=40, n_estimators=500; total time=   3.6s
# [CV] END criterion=entropy, max_depth=2, min_samples_split=40, n_estimators=500; total time=   3.8s
# [CV] END criterion=entropy, max_depth=2, min_samples_split=40, n_estimators=500; total time=   3.6s
# [CV] END criterion=entropy, max_depth=2, min_samples_split=40, n_estimators=500; total time=   3.5s
# [CV] END criterion=entropy, max_depth=2, min_samples_split=40, n_estimators=500; total time=   3.8s
# RandomizedSearchCV(cv=5, estimator=RandomForestClassifier(), n_jobs=1,
#                    param_distributions={'criterion': ['gini', 'entropy'],
#                                         'max_depth': [2, 3, 4, 5, None],
#                                         'min_samples_split': [10, 20, 30, 40,
#                                                               50],
#                                         'n_estimators': [10, 500, 100, 2000]},
#                    verbose=2)

# %%
#PREDICT USING THE TRAINED MODEL
classes=rf_g.predict(test_x)

# %% [markdown]
# #ACCURACY SCORE-RandomForestClassifier using RandomizedSearchC

# %%
#PRECISION AND RECALL
print("ACCUIRACY SCORE")
print(metrics.accuracy_score(test_y,classes))
# Out:
# ACCUIRACY SCORE
# 0.8694610778443114

# %%
#PRECISION RECALL MATRIX
print("precision/recall Metrics")
print(metrics.classification_report(test_y,classes))
# Out:
# precision/recall Metrics
#               precision    recall  f1-score   support
#
#            0       0.87      0.86      0.87       559
#            1       0.87      0.87      0.87       550
#            2       0.87      0.88      0.87       561
#
#     accuracy                           0.87      1670
#    macro avg       0.87      0.87      0.87      1670
# weighted avg       0.87      0.87      0.87      1670

# %%
#CONFUSION MATRIX
print("CONFUSION MATRIX")
cf=metrics.confusion_matrix(test_y,classes)
lbl1=["Predicted 0","Predicted 1","Predicted 2"]
lbl2=["True 0","True 1","True 2"]
sns.heatmap(cf,annot=True,cmap="Greens",fmt="d",xticklabels=lbl1,yticklabels=lbl2)
plt.show()
# Out:
# CONFUSION MATRIX

# %%
# !jupyter nbconvert HDFCpercdiff_0_7D1D10_SMP_DT_RF.ipynb
# Out:
# [NbConvertApp] Converting notebook HDFCpercdiff_0_7D1D10_SMP_DT_RF.ipynb to html
# [NbConvertApp] Writing 438031 bytes to HDFCpercdiff_0_7D1D10_SMP_DT_RF.html
