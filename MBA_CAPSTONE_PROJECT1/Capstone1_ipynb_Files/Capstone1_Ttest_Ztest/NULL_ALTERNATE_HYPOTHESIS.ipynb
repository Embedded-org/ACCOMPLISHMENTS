# %%
#Importing the Libraries
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib. pyplot as plt
import matplotlib
import sklearn
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
all_data=pd.read_csv("HDFCBANK.csv",na_values=None,index_col='Date',parse_dates=True,infer_datetime_format=True)
all_data.head()
# Out:
#               Symbol Series  Prev Close    Open    High     Low    Last  \
# Date
# 2000-01-03  HDFCBANK     EQ      157.40  166.00  170.00  166.00  170.00
# 2000-01-04  HDFCBANK     EQ      170.00  182.00  183.45  171.00  174.00
# 2000-01-05  HDFCBANK     EQ      173.80  170.00  173.90  165.00  168.00
# 2000-01-06  HDFCBANK     EQ      166.95  168.00  170.00  165.30  168.95
# 2000-01-07  HDFCBANK     EQ      168.30  162.15  171.00  162.15  170.75
#
#              Close    VWAP  Volume      Turnover  Trades  Deliverable Volume  \
# Date
# 2000-01-03  170.00  169.52   33259  5.638122e+11     NaN                 NaN
# 2000-01-04  173.80  174.99  168710  2.952261e+12     NaN                 NaN
# 2000-01-05  166.95  169.20  159820  2.704094e+12     NaN                 NaN
# 2000-01-06  168.30  168.44   85026  1.432166e+12     NaN                 NaN
# 2000-01-07  168.35  166.79   85144  1.420158e+12     NaN                 NaN
#
#             %Deliverble
# Date
# ...

# %%
features = ['Close']
eval_data= pd.DataFrame(columns=features, data=all_data, index=all_data.index)
eval_data.head()
# Out:
#              Close
# Date
# 2000-01-03  170.00
# 2000-01-04  173.80
# 2000-01-05  166.95
# 2000-01-06  168.30
# 2000-01-07  168.35

# %%
# line plot - the yearly accumulated rainfall in Barcelona
eval_data.plot(color='steelblue', linewidth=3, figsize=(12,6))

# modify ticks size
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.legend('')

# title and labels
plt.title('The close values of HDFCBANK stock equity', fontsize=20)
plt.xlabel('Year', fontsize=16)
plt.ylabel('close values', fontsize=16)
# Out:
# (array([728659., 730120., 731581., 733042., 734503., 735964., 737425.,
#         738886.]), <a list of 8 Text major ticklabel objects>)
# (array([   0.,  500., 1000., 1500., 2000., 2500., 3000.]),
#  <a list of 7 Text major ticklabel objects>)
# Text(0.5, 1.0, 'The close values of HDFCBANK stock equity')
# Text(0.5, 0, 'Year')
# Text(0, 0.5, 'close values')

# %%
eval_data['SMA_7'] = eval_data['Close'].rolling(7, min_periods=1).mean()

# %%
eval_data.head()
# Out:
#              Close     SMA_7
# Date
# 2000-01-03  170.00  170.0000
# 2000-01-04  173.80  171.9000
# 2000-01-05  166.95  170.2500
# 2000-01-06  168.30  169.7625
# 2000-01-07  168.35  169.4800

# %%
# colors for the line plot
colors = ['green', 'red']

# line plot - the yearly average air temperature in Barcelona
eval_data.plot(color=colors, linewidth=1.5, figsize=(12,6))

# modify ticks size
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.legend(labels =['close values', '7-days SMA'], fontsize=14)

# title and labels
plt.title('The close values of HDFCBANK stock equity', fontsize=20)
plt.xlabel('Year', fontsize=16)
plt.ylabel('close values', fontsize=16)
# Out:
# (array([728659., 730120., 731581., 733042., 734503., 735964., 737425.,
#         738886.]), <a list of 8 Text major ticklabel objects>)
# (array([   0.,  500., 1000., 1500., 2000., 2500., 3000.]),
#  <a list of 7 Text major ticklabel objects>)
# Text(0.5, 1.0, 'The close values of HDFCBANK stock equity')
# Text(0.5, 0, 'Year')
# Text(0, 0.5, 'close values')

# %%
eval_data['SMA_13'] = eval_data['Close'].rolling(13, min_periods=1).mean()
eval_data['SMA_20'] = eval_data['Close'].rolling(20, min_periods=1).mean()
eval_data['SMA_100'] = eval_data['Close'].rolling(100, min_periods=1).mean()
eval_data['SMA_200'] = eval_data['Close'].rolling(200, min_periods=1).mean()

# %%
import matplotlib.pyplot as plt
# plot lines
plt.figure(figsize=(14, 6))
plt.title('The close values of HDFCBANK stock equity', fontsize=20)
plt.xlabel('Year', fontsize=16)
plt.ylabel('close values', fontsize=16)
plt.plot(eval_data.index,eval_data['Close'], label = "Close", linestyle="-.",color='green',linewidth=13.5)
plt.plot(eval_data.index,eval_data['SMA_7'], label = "SMA_7", linestyle="solid",color='red',linewidth=11.5)
plt.plot(eval_data.index,eval_data['SMA_13'], label = "SMA_13", linestyle="solid",color='purple',linewidth=9.5)
plt.plot(eval_data.index,eval_data['SMA_20'], label = "SMA_20", linestyle="solid",color='orange',linewidth=7.5)
plt.plot(eval_data.index,eval_data['SMA_100'], label = "SMA_100", linestyle="solid",color='steelblue',linewidth=5.5)
plt.plot(eval_data.index,eval_data['SMA_200'], label = "SMA_200", linestyle="solid",color='deeppink',linewidth=1.5)
plt.legend()
plt.show()
# Out:
# Text(0.5, 1.0, 'The close values of HDFCBANK stock equity')
# Text(0.5, 0, 'Year')
# Text(0, 0.5, 'close values')

# %%
eval_data.head()
# Out:
#              Close     SMA_7    SMA_13    SMA_20   SMA_100   SMA_200
# Date
# 2000-01-03  170.00  170.0000  170.0000  170.0000  170.0000  170.0000
# 2000-01-04  173.80  171.9000  171.9000  171.9000  171.9000  171.9000
# 2000-01-05  166.95  170.2500  170.2500  170.2500  170.2500  170.2500
# 2000-01-06  168.30  169.7625  169.7625  169.7625  169.7625  169.7625
# 2000-01-07  168.35  169.4800  169.4800  169.4800  169.4800  169.4800

# %%
eval_data['EMA_7'] = eval_data['Close'].ewm(span=7, adjust=False).mean()
eval_data['EMA_13'] = eval_data['Close'].ewm(span=7, adjust=False).mean()
eval_data['EMA_20'] = eval_data['Close'].ewm(span=7, adjust=False).mean()
eval_data['EMA_100'] = eval_data['Close'].ewm(span=7, adjust=False).mean()
eval_data['EMA_200'] = eval_data['Close'].ewm(span=7, adjust=False).mean()

# %%
eval_data.head()
# Out:
#              Close     SMA_7    SMA_13    SMA_20   SMA_100   SMA_200  \
# Date
# 2000-01-03  170.00  170.0000  170.0000  170.0000  170.0000  170.0000
# 2000-01-04  173.80  171.9000  171.9000  171.9000  171.9000  171.9000
# 2000-01-05  166.95  170.2500  170.2500  170.2500  170.2500  170.2500
# 2000-01-06  168.30  169.7625  169.7625  169.7625  169.7625  169.7625
# 2000-01-07  168.35  169.4800  169.4800  169.4800  169.4800  169.4800
#
#                  EMA_7      EMA_13      EMA_20     EMA_100     EMA_200
# Date
# 2000-01-03  170.000000  170.000000  170.000000  170.000000  170.000000
# 2000-01-04  170.950000  170.950000  170.950000  170.950000  170.950000
# 2000-01-05  169.950000  169.950000  169.950000  169.950000  169.950000
# 2000-01-06  169.537500  169.537500  169.537500  169.537500  169.537500
# 2000-01-07  169.240625  169.240625  169.240625  169.240625  169.240625

# %%
import matplotlib.pyplot as plt
# plot lines
plt.figure(figsize=(14, 6))
plt.title('The close values of HDFCBANK stock equity', fontsize=20)
plt.xlabel('Year', fontsize=16)
plt.ylabel('close values', fontsize=16)
plt.plot(eval_data.index,eval_data['Close'], label = "Close", linestyle="-.",color='green',linewidth=13.5)
plt.plot(eval_data.index,eval_data['EMA_7'], label = "EMA_7", linestyle="solid",color='red',linewidth=11.5)
plt.plot(eval_data.index,eval_data['EMA_13'], label = "EMA_13", linestyle="solid",color='purple',linewidth=9.5)
plt.plot(eval_data.index,eval_data['EMA_20'], label = "EMA_20", linestyle="solid",color='orange',linewidth=7.5)
plt.plot(eval_data.index,eval_data['EMA_100'], label = "EMA_100", linestyle="solid",color='steelblue',linewidth=5.5)
plt.plot(eval_data.index,eval_data['EMA_200'], label = "EMA_200", linestyle="solid",color='deeppink',linewidth=1.5)
plt.legend()
plt.show()
# Out:
# Text(0.5, 1.0, 'The close values of HDFCBANK stock equity')
# Text(0.5, 0, 'Year')
# Text(0, 0.5, 'close values')

# %%
eval_data.head()
eval_data.info()
# Out:
#              Close     SMA_7    SMA_13    SMA_20   SMA_100   SMA_200  \
# Date
# 2000-01-03  170.00  170.0000  170.0000  170.0000  170.0000  170.0000
# 2000-01-04  173.80  171.9000  171.9000  171.9000  171.9000  171.9000
# 2000-01-05  166.95  170.2500  170.2500  170.2500  170.2500  170.2500
# 2000-01-06  168.30  169.7625  169.7625  169.7625  169.7625  169.7625
# 2000-01-07  168.35  169.4800  169.4800  169.4800  169.4800  169.4800
#
#                  EMA_7      EMA_13      EMA_20     EMA_100     EMA_200
# Date
# 2000-01-03  170.000000  170.000000  170.000000  170.000000  170.000000
# 2000-01-04  170.950000  170.950000  170.950000  170.950000  170.950000
# 2000-01-05  169.950000  169.950000  169.950000  169.950000  169.950000
# 2000-01-06  169.537500  169.537500  169.537500  169.537500  169.537500
# 2000-01-07  169.240625  169.240625  169.240625  169.240625  169.240625
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 5306 entries, 2000-01-03 to 2021-04-30
# ...

# %%
Close_list = eval_data['Close'].tolist()
SMA_7_list=eval_data['SMA_7'].tolist()
close_list_small=Close_list[0:21]
#close_list_small
len(Close_list)
# Out:
# 5306

# %%
import scipy.stats as stats
t_statistic, p_value = stats.ttest_1samp(close_list_small, popmean=close_list_small[19])
print(t_statistic , p_value)
# Out:
# -8.673775246918524 3.269174659934147e-08

# %%
true_count=0
false_count=0
flag=100
if(p_value)<0.05:
  print("Reject NULL hypothesis")
  if(close_list_small[19]<SMA_7_list[19]):
    flag=1
    print("stock price is likely to increase tomorrow\n","previous day value is:",close_list_small[19],"moving average is:",SMA_7_list[19])
  else:
    flag=0
    print("stock price is likely to decrease tomorrow","previous day value is:",close_list_small[19],"moving average is:",SMA_7_list[19])
else:
  flag=2
  print("Accept NULL hypothesis")
  print("previous value is equal to",close_list_small[19])

if(flag==1 and close_list_small[20]>close_list_small[19]):
  true_count=true_count+1
elif(flag==1 and close_list_small[20]<close_list_small[19]):
  false_count=false_count+1
if(flag==0 and close_list_small[20]<close_list_small[19]):
  true_count=true_count+1
elif(flag==0 and close_list_small[20]>close_list_small[19]):
  false_count=false_count+1
if(flag==2 and close_list_small[20]==close_list_small[19]):
  true_count=true_count+1
elif(flag==2 and close_list_small[20]!=close_list_small[19]):
  false_count=false_count+1

print("previous vale is:",close_list_small[19])
print("next day value is:",close_list_small[20])
print("true count is",true_count)
print("false count is",false_count)
# Out:
# Reject NULL hypothesis
# stock price is likely to decrease tomorrow previous day value is: 237.75 moving average is: 211.32142857142858
# previous vale is: 237.75
# next day value is: 240.95
# true count is 0
# false count is 1

# %% [markdown]
# Determine the hypothesis
#
# H0 : population mean is greater or equal to sample mean (μ> = x)
#
# H1 : population mean is less than sample mean (μ< x)

# %%
import numpy as np
from scipy import stats

# %%
mean = np.mean(close_list_small)

# %%
std_error = np.std(close_list_small) / np.sqrt(len(close_list_small))

# %% [markdown]
# According to the formula we need sample mean and standard error. The formula for the standard error is:
#
# standard error= (s / √n)
#
# Where,
#
# s  = standard deviation of the sample
#
# n  = sample size
#
# np.std() is used for calculating the standard deviation
#
# np.sqrt(len()) is used to calculate the square root of sample size
#
# Let’s calculate the t-static, t-critical and p-value for the comparison.

# %% [markdown]
# **calculate t statistics:**

# %%
popmean=close_list_small[19]
popmean
t = abs(mean - popmean) / std_error
print('t static:',t)
# Out:
# 237.75
# t static: 8.887974791017317

# %% [markdown]
# **two-tailed critical value at alpha = 0.05**

# %%
t_crit = stats.t.ppf(q=0.975, df=13)
print("Critical value for t two tailed:",t_crit)
# Out:
# Critical value for t two tailed: 2.1603686564610127

# %% [markdown]
# **one-tailed critical value at alpha = 0.05**

# %%
t_crit = stats.t.ppf(q=0.95, df=13)
print("Critical value for t one tailed:",t_crit)
# Out:
# Critical value for t one tailed: 1.7709333959867988

# %% [markdown]
# **get two-tailed p value**

# %%
p_value = 2*(1-stats.t.cdf(x=t, df=13))
print("p-value:",p_value)
# Out:
# p-value: 6.937140661911201e-07

# %% [markdown]
# So with the help of the above line of codes, we got the value of t-static, t-critical and p-value. Since the p-value is greater than the alpha value, we are in support of the null hypothesis. Therefore the population mean is greater than the sample mean.

# %% [markdown]
# Hypothesis
# H0: There is no significant mean difference in systolic blood pressure. i.e., μ= popmean
#
# H1: The population mean is less than popmean. i.e., μ < popmean

# %%
print("popmean",popmean)
from scipy import stats
t_value,p_value=stats.ttest_1samp(close_list_small,popmean)

one_tailed_p_value=p_value/2 # Since alternative hypothesis is one tailed, We need to divide the p value by 2.

print("Test statistic is ",t_value)

print("p-value for one tailed test is",one_tailed_p_value)
print("p-value for two tailed test is",p_value)

alpha = 0.05

if one_tailed_p_value<=alpha:

    print('Conclusion','n',"Since p-value=",one_tailed_p_value,'<',"alpha",alpha,'''We reject the null hypothesis H0. 

So we conclude that there is no significant mean difference in systolic blood pressure. i.e.,μ'''

"<",popmean,"at alpha=",alpha, '''level of significance''')

else:

    print('Conclusion','n','Since p-value(=%f)'%one_tailed_p_value,'>','alpha(=%.2f)'%alpha,'''We do not reject the null hypothesis H0.
    i.e.,μ''' ">=",popmean,"at alpha=",alpha, '''level of significance''')
# Out:
# popmean 237.75
# Test statistic is  -8.673775246918524
# p-value for one tailed test is 1.6345873299670736e-08
# p-value for two tailed test is 3.269174659934147e-08
# Conclusion n Since p-value= 1.6345873299670736e-08 < alpha 0.05 We reject the null hypothesis H0.
#
# So we conclude that there is no significant mean difference in systolic blood pressure. i.e.,μ< 237.75 at alpha= 0.05 level of significance

# %%
import scipy
scipy.stats.t.sf(abs(t_value), df=19)
# Out:
# 2.470584209035695e-08
