# %%
#Importing the Libraries
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib. pyplot as plt
import matplotlib
import sklearn
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
all_data=pd.read_csv("HDFCBANK.csv",na_values=None,index_col='Date',parse_dates=True,infer_datetime_format=True)
all_data.head()
# Out:
#               Symbol Series  Prev Close    Open    High     Low    Last  \
# Date
# 2000-01-03  HDFCBANK     EQ      157.40  166.00  170.00  166.00  170.00
# 2000-01-04  HDFCBANK     EQ      170.00  182.00  183.45  171.00  174.00
# 2000-01-05  HDFCBANK     EQ      173.80  170.00  173.90  165.00  168.00
# 2000-01-06  HDFCBANK     EQ      166.95  168.00  170.00  165.30  168.95
# 2000-01-07  HDFCBANK     EQ      168.30  162.15  171.00  162.15  170.75
#
#              Close    VWAP  Volume      Turnover  Trades  Deliverable Volume  \
# Date
# 2000-01-03  170.00  169.52   33259  5.638122e+11     NaN                 NaN
# 2000-01-04  173.80  174.99  168710  2.952261e+12     NaN                 NaN
# 2000-01-05  166.95  169.20  159820  2.704094e+12     NaN                 NaN
# 2000-01-06  168.30  168.44   85026  1.432166e+12     NaN                 NaN
# 2000-01-07  168.35  166.79   85144  1.420158e+12     NaN                 NaN
#
#             %Deliverble
# Date
# 2000-01-03          NaN
# 2000-01-04          NaN
# 2000-01-05          NaN
# 2000-01-06          NaN
# 2000-01-07          NaN

# %%
features = ['Close']
eval_data= pd.DataFrame(columns=features, data=all_data, index=all_data.index)
eval_data.head()
# Out:
#              Close
# Date
# 2000-01-03  170.00
# 2000-01-04  173.80
# 2000-01-05  166.95
# 2000-01-06  168.30
# 2000-01-07  168.35

# %%
# line plot - the yearly accumulated rainfall in Barcelona
eval_data.plot(color='steelblue', linewidth=3, figsize=(12,6))

# modify ticks size
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.legend('')

# title and labels
plt.title('The close values of HDFCBANK stock equity', fontsize=20)
plt.xlabel('Year', fontsize=16)
plt.ylabel('close values', fontsize=16)
# Out:
# (array([728659., 730120., 731581., 733042., 734503., 735964., 737425.,
#         738886.]), <a list of 8 Text major ticklabel objects>)
# (array([   0.,  500., 1000., 1500., 2000., 2500., 3000.]),
#  <a list of 7 Text major ticklabel objects>)
# Text(0.5, 1.0, 'The close values of HDFCBANK stock equity')
# Text(0.5, 0, 'Year')
# Text(0, 0.5, 'close values')

# %%
eval_data['SMA_20']= eval_data['Close'].rolling(20, min_periods=1).mean()

# %%
eval_data.head(20)
eval_data.info()
# Out:
#              Close      SMA_20
# Date
# 2000-01-03  170.00  170.000000
# 2000-01-04  173.80  171.900000
# 2000-01-05  166.95  170.250000
# 2000-01-06  168.30  169.762500
# 2000-01-07  168.35  169.480000
# 2000-01-10  165.90  168.883333
# 2000-01-11  163.40  168.100000
# 2000-01-12  165.45  167.768750
# 2000-01-13  165.10  167.472222
# 2000-01-14  165.45  167.270000
# 2000-01-17  178.70  168.309091
# 2000-01-18  165.70  168.091667
# 2000-01-19  179.00  168.930769
# 2000-01-20  178.60  169.621429
# 2000-01-21  188.15  170.856667
# 2000-01-24  200.55  172.712500
# 2000-01-25  216.60  175.294118
# 2000-01-27  229.70  178.316667
# 2000-01-28  227.90  180.926316
# 2000-01-31  237.75  183.767500
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 5306 entries, 2000-01-03 to 2021-04-30
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Close   5306 non-null   float64
#  1   SMA_20  5306 non-null   float64
# dtypes: float64(2)
# memory usage: 124.4 KB

# %%
import matplotlib.pyplot as plt
# plot lines
plt.figure(figsize=(12, 6))
plt.title('The close values of HDFCBANK stock equity', fontsize=20)
plt.xlabel('Year', fontsize=16)
plt.ylabel('close values', fontsize=16)
plt.plot(eval_data.index,eval_data['Close'], color='green',linewidth=1.5)
plt.plot(eval_data.index,eval_data['SMA_20'],color='red',linewidth=1.5)
plt.legend(labels =['close values', '20-days SMA'], fontsize=14)
plt.show()
# Out:
# Text(0.5, 1.0, 'The close values of HDFCBANK stock equity')
# Text(0.5, 0, 'Year')
# Text(0, 0.5, 'close values')

# %%
#!pip install pmdarima

# %%
import sys
print("python version",sys.version)
import numpy
print("numpy version",numpy.__version__)
import scipy
print("scipy version",scipy.__version__)
import sklearn
print("scikit -learn version",sklearn.__version__)
import pandas
print("pandas version",pandas.__version__)
import statsmodels
print("statsmodels version",statsmodels.__version__)
import pmdarima
print("pyramid version",pmdarima.__version__)
import pip
print("pip version",pip.__version__)
# Out:
# python version 3.7.13 (default, Apr 24 2022, 01:04:09)
# [GCC 7.5.0]
# numpy version 1.21.6
# scipy version 1.4.1
# scikit -learn version 1.0.2
# pandas version 1.3.5
# statsmodels version 0.13.2
# pyramid version 1.8.5
# pip version 21.1.3

# %%
import warnings
import numpy as np
import pandas as pd
import itertools
import matplotlib.pyplot as plt
import seaborn as sns
import scipy
# %matplotlib inline
from matplotlib.pylab import rcParams
import statsmodels.api as sm
from statsmodels.tsa.seasonal import seasonal_decompose
import pmdarima as pm
from sklearn import metrics
from pmdarima.arima import auto_arima
warnings.filterwarnings('ignore')
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity="all"

# %%
features = ['SMA_20']
df1=eval_data[features]
df1.head()
# Out:
#               SMA_20
# Date
# 2000-01-03  170.0000
# 2000-01-04  171.9000
# 2000-01-05  170.2500
# 2000-01-06  169.7625
# 2000-01-07  169.4800

# %%
df1.index = pd.to_datetime(df1.index)
df2=df1.resample('1M').mean()
df2.head()
# Out:
#                 SMA_20
# Date
# 2000-01-31  171.385676
# 2000-02-29  219.282024
# 2000-03-31  248.086429
# 2000-04-30  245.559444
# 2000-05-31  244.106818

# %%
df2.head()
df2.tail()
df2.shape
df2.info()
df2.describe()
# Out:
#                 SMA_20
# Date
# 2000-01-31  171.385676
# 2000-02-29  219.282024
# 2000-03-31  248.086429
# 2000-04-30  245.559444
# 2000-05-31  244.106818
#                  SMA_20
# Date
# 2020-12-31  1395.265568
# 2021-01-31  1426.213125
# 2021-02-28  1512.656250
# 2021-03-31  1553.858929
# 2021-04-30  1467.761842
# (256, 1)
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 256 entries, 2000-01-31 to 2021-04-30
# Freq: M
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   SMA_20  256 non-null    float64
# dtypes: float64(1)
# memory usage: 4.0 KB
#             SMA_20
# count   256.000000
# mean   1006.949991
# std     631.886968
# min     171.385676
# 25%     479.847319
# 50%     945.383182
# 75%    1415.173594
# max    2422.290109

# %%
plt.figure(figsize=(15,10))
plt.plot(df2)
plt.xlabel('Time')
plt.ylabel('SMA_20')
plt.title("# SMA_20 over time")
plt.show;

# %%
decomposition=seasonal_decompose(df2,model='multiplicative',extrapolate_trend='freq')
trend=decomposition.trend
seasonal=decomposition.seasonal
residual=decomposition.resid

# %%
plt.figure(figsize=(20,10))
plt.subplot(221)
plt.plot(df2,color='#00b8ff',label='original')
plt.legend(loc='best',fontsize=20)
plt.subplot(222)
plt.plot(trend,'b',label='Trend')
plt.legend(loc='best',fontsize=20)
plt.subplot(223)
plt.plot(seasonal,color='#00b8ff',label='sesonality')
plt.legend(loc='best',fontsize=20)
plt.subplot(224)
plt.plot(residual,'y',label='Residuals')
plt.legend(loc='best',fontsize=20)
plt.tight_layout()
plt.show()

# %%
decomposition.plot()

# %%
decomposition=seasonal_decompose(df2,model='additive')

# %%
plt.figure(figsize=(20,10))
trend=decomposition.trend
seasonal=decomposition.seasonal
residual=decomposition.resid
plt.subplot(221)
plt.plot(df2,color='#00b8ff',label='original')
plt.legend(loc='best',fontsize=20)
plt.subplot(222)
plt.plot(trend,'b',label='Trend')
plt.legend(loc='best',fontsize=20)
plt.subplot(223)
plt.plot(seasonal,color='#00b8ff',label='sesonality')
plt.legend(loc='best',fontsize=20)
plt.subplot(224)
plt.plot(residual,'y',label='Residuals')
plt.legend(loc='best',fontsize=20)
plt.tight_layout()
plt.show()

# %%
decomposition.plot()

# %%
from pmdarima.arima.stationarity import ADFTest
adf_test=ADFTest(alpha=0.05)
adf_test.should_diff (df2)
# Out:
# (0.15644271556702916, True)

# %%
# Loading the packages
import pandas as pd
from statsmodels.graphics import tsaplots
plt.style.use('fivethirtyeight')

# Display the autocorrelation plot of your time series
fig = tsaplots.plot_acf(df2, lags=24)
plt.show()

# Display the partial autocorrelation plot of your time series
fig = tsaplots.plot_pacf(df2, lags=24)
plt.show()

# %%
train,test=df2[:240],df2[240:]
train.shape
test.shape
# Out:
# (240, 1)
# (16, 1)

# %%
import matplotlib.pyplot as plt
# plot lines
plt.figure(figsize=(12, 6))
plt.title('The Train vs Train of HDFCBANK stock equity', fontsize=20)
plt.xlabel('Year', fontsize=16)
plt.ylabel('Train Data vs Test Data', fontsize=16)
plt.plot(train, color='green',linewidth=1.5)
plt.plot(test,color='red',linewidth=1.5)
plt.legend(labels =['train-data', 'test-data'], fontsize=14)
plt.show()
# Out:
# Text(0.5, 1.0, 'The Train vs Train of HDFCBANK stock equity')
# Text(0.5, 0, 'Year')
# Text(0, 0.5, 'Train Data vs Test Data')

# %%
#fitting a stepwise model:
Arima_model=auto_arima(train,start_p=0,start_q=2,max_p=13,max_q=4,start_P=0,start_Q=0,max_P=8,max_Q=8,
                       m=12,seasonal=True,trace=True,error_action='warn',suppress_warnings=False,stepwise=True,random_state=20,n_fits=30)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(0,1,2)(0,0,0)[12] intercept   : AIC=2970.495, Time=0.53 sec
#  ARIMA(0,1,0)(0,0,0)[12] intercept   : AIC=2992.486, Time=0.05 sec
#  ARIMA(1,1,0)(1,0,0)[12] intercept   : AIC=2972.054, Time=0.27 sec
#  ARIMA(0,1,1)(0,0,1)[12] intercept   : AIC=2970.327, Time=0.58 sec
#  ARIMA(0,1,0)(0,0,0)[12]             : AIC=2990.803, Time=0.01 sec
#  ARIMA(0,1,1)(0,0,0)[12] intercept   : AIC=2968.594, Time=0.14 sec
#  ARIMA(0,1,1)(1,0,0)[12] intercept   : AIC=2970.303, Time=0.46 sec
#  ARIMA(0,1,1)(1,0,1)[12] intercept   : AIC=2972.006, Time=0.90 sec
#  ARIMA(1,1,1)(0,0,0)[12] intercept   : AIC=2970.489, Time=0.24 sec
#  ARIMA(1,1,0)(0,0,0)[12] intercept   : AIC=2970.247, Time=0.09 sec
#  ARIMA(1,1,2)(0,0,0)[12] intercept   : AIC=2972.496, Time=0.32 sec
#  ARIMA(0,1,1)(0,0,0)[12]             : AIC=2966.796, Time=0.05 sec
#  ARIMA(0,1,1)(1,0,0)[12]             : AIC=2968.532, Time=0.14 sec
#  ARIMA(0,1,1)(0,0,1)[12]             : AIC=2968.555, Time=0.18 sec
#  ARIMA(0,1,1)(1,0,1)[12]             : AIC=2970.230, Time=0.54 sec
#  ARIMA(1,1,1)(0,0,0)[12]             : AIC=2968.685, Time=0.06 sec
#  ARIMA(0,1,2)(0,0,0)[12]             : AIC=2968.692, Time=0.07 sec
#  ARIMA(1,1,0)(0,0,0)[12]             : AIC=2968.422, Time=0.04 sec
#  ARIMA(1,1,2)(0,0,0)[12]             : AIC=2970.684, Time=0.15 sec
#
# Best model:  ARIMA(0,1,1)(0,0,0)[12]
# Total fit time: 4.981 seconds

# %%
Arima_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  240
# Model:               SARIMAX(0, 1, 1)   Log Likelihood               -1481.398
# Date:                Tue, 12 Jul 2022   AIC                           2966.796
# Time:                        03:56:14   BIC                           2973.749
# Sample:                             0   HQIC                          2969.598
#                                 - 240
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1          0.3320      0.032     10.450      0.000       0.270       0.394
# sigma2      1.416e+04    256.824     55.137      0.000    1.37e+04    1.47e+04
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.01   Jarque-Bera (JB):             68560.51
# Prob(Q):                              0.91   Prob(JB):                         0.00
# Heteroskedasticity (H):              15.97   Skew:                            -7.57
# Prob(H) (two-sided):                  0.00   Kurtosis:                        84.58
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
prediction=pd.DataFrame(Arima_model.predict(n_periods=16),index=test.index)
prediction.columns=['Predicted_SMA_20']
prediction
# Out:
#             Predicted_SMA_20
# Date
# 2020-01-31        1261.49414
# 2020-02-29        1261.49414
# 2020-03-31        1261.49414
# 2020-04-30        1261.49414
# 2020-05-31        1261.49414
# 2020-06-30        1261.49414
# 2020-07-31        1261.49414
# 2020-08-31        1261.49414
# 2020-09-30        1261.49414
# 2020-10-31        1261.49414
# 2020-11-30        1261.49414
# 2020-12-31        1261.49414
# 2021-01-31        1261.49414
# 2021-02-28        1261.49414
# 2021-03-31        1261.49414
# 2021-04-30        1261.49414

# %%
plt.figure(figsize=(15,10))
plt.plot(train,label='Training')
plt.plot(test,label='Test')
plt.plot(prediction,label='Predicted')
plt.legend(loc='upper center')
plt.show()

# %%
test['Predicted_SMA_20']=prediction
test['Error']=test['SMA_20']-test['Predicted_SMA_20']
test
# Out:
#                  SMA_20  Predicted_SMA_20       Error
# Date
# 2020-01-31  1270.653478        1261.49414    9.159338
# 2020-02-29  1234.681250        1261.49414  -26.812890
# 2020-03-31  1124.135238        1261.49414 -137.358902
# 2020-04-30   896.665833        1261.49414 -364.828307
# 2020-05-31   917.564605        1261.49414 -343.929535
# 2020-06-30   954.297500        1261.49414 -307.196640
# 2020-07-31  1066.916957        1261.49414 -194.577184
# 2020-08-31  1067.592262        1261.49414 -193.901878
# 2020-09-30  1091.766932        1261.49414 -169.727209
# 2020-10-31  1128.489286        1261.49414 -133.004855
# 2020-11-30  1272.824750        1261.49414   11.330610
# 2020-12-31  1395.265568        1261.49414  133.771428
# 2021-01-31  1426.213125        1261.49414  164.718985
# 2021-02-28  1512.656250        1261.49414  251.162110
# 2021-03-31  1553.858929        1261.49414  292.364788
# 2021-04-30  1467.761842        1261.49414  206.267702

# %% [markdown]
# **STEP6-EVALUATE MODEL PERFORMANCE for SMA_20ARIMA**

# %% [markdown]
# **MEAN ABSOLUTE ERROR (MAE) FOR TEST DATA**

# %%
from sklearn.metrics import mean_absolute_error
print("MEAN ABSOLUTE ERROR (MAE) FOR TEST DATA IS")
np.round(mean_absolute_error(test.SMA_20,test.Predicted_SMA_20),3)
# Out:
# MEAN ABSOLUTE ERROR (MAE) FOR TEST DATA IS
# 183.757

# %% [markdown]
# **MEAN SQUARE ERROR (MSE) FOR TEST DATA**

# %%
from sklearn.metrics import mean_squared_error
print("MEAN SQUARE ERROR (MSE) FOR TEST DATA IS")
mse=np.round(mean_squared_error(test.SMA_20,test.Predicted_SMA_20),3)
mse
# Out:
# MEAN SQUARE ERROR (MSE) FOR TEST DATA IS
# 45227.786

# %% [markdown]
# **ROOT MEAN SQUARE ERROR (MSE) FOR TEST DATA**

# %%
import math
math.sqrt(mse)
# Out:
# 212.66825339010992

# %% [markdown]
# **MEDIAN ABSOLUTE ERROR (MAE) FOR TEST DATA**

# %%
from sklearn.metrics import median_absolute_error
print("MEDIAN ABSOLUTE ERROR (MAE) FOR TEST DATA IS")
np.round(median_absolute_error(test.SMA_20,test.Predicted_SMA_20),3)
# Out:
# MEDIAN ABSOLUTE ERROR (MAE) FOR TEST DATA IS
# 181.815

# %% [markdown]
# **Mean Absolute Percentage Error FOR TEST DATA**

# %%
print("MAPE FOR TEST DATA IS")
mape1 = np.mean(np.abs((test.SMA_20-test.Predicted_SMA_20)/test.SMA_20))*100
np.round(mape1,3)
# Out:
# MAPE FOR TEST DATA IS
# 16.294

# %%
train_log=np.log(train)
train_log.head()
train.plot()
train_log.plot()
plt.show()
# Out:
#               SMA_20
# Date
# 2000-01-31  5.143916
# 2000-02-29  5.390359
# 2000-03-31  5.513777
# 2000-04-30  5.503539
# 2000-05-31  5.497606

# %%
#fitting a stepwise model:
Arima_model=auto_arima(train_log,start_p=0,start_q=0,max_p=14,max_q=5,start_P=0,start_Q=0,max_P=8,max_Q=8,
                       m=12,seasonal=True,trace=True,error_action='warn',suppress_warnings=False,stepwise=True,random_state=20,n_fits=30)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(0,1,0)(0,0,0)[12] intercept   : AIC=-403.413, Time=0.08 sec
#  ARIMA(1,1,0)(1,0,0)[12] intercept   : AIC=-426.829, Time=0.35 sec
#  ARIMA(0,1,1)(0,0,1)[12] intercept   : AIC=-430.360, Time=0.36 sec
#  ARIMA(0,1,0)(0,0,0)[12]             : AIC=-403.847, Time=0.03 sec
#  ARIMA(0,1,1)(0,0,0)[12] intercept   : AIC=-432.186, Time=0.09 sec
#  ARIMA(0,1,1)(1,0,0)[12] intercept   : AIC=-430.381, Time=0.23 sec
#  ARIMA(0,1,1)(1,0,1)[12] intercept   : AIC=-428.799, Time=0.98 sec
#  ARIMA(1,1,1)(0,0,0)[12] intercept   : AIC=-430.211, Time=0.18 sec
#  ARIMA(0,1,2)(0,0,0)[12] intercept   : AIC=-430.213, Time=0.17 sec
#  ARIMA(1,1,0)(0,0,0)[12] intercept   : AIC=-428.614, Time=0.13 sec
#  ARIMA(1,1,2)(0,0,0)[12] intercept   : AIC=-428.222, Time=0.15 sec
#  ARIMA(0,1,1)(0,0,0)[12]             : AIC=-433.168, Time=0.04 sec
#  ARIMA(0,1,1)(1,0,0)[12]             : AIC=-431.297, Time=0.14 sec
#  ARIMA(0,1,1)(0,0,1)[12]             : AIC=-431.282, Time=0.18 sec
#  ARIMA(0,1,1)(1,0,1)[12]             : AIC=-429.706, Time=0.43 sec
#  ARIMA(1,1,1)(0,0,0)[12]             : AIC=-431.211, Time=0.11 sec
#  ARIMA(0,1,2)(0,0,0)[12]             : AIC=-431.212, Time=0.09 sec
#  ARIMA(1,1,0)(0,0,0)[12]             : AIC=-429.730, Time=0.04 sec
#  ARIMA(1,1,2)(0,0,0)[12]             : AIC=-429.214, Time=0.07 sec
#
# Best model:  ARIMA(0,1,1)(0,0,0)[12]
# Total fit time: 3.919 seconds

# %%
Arima_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  240
# Model:               SARIMAX(0, 1, 1)   Log Likelihood                 218.584
# Date:                Tue, 12 Jul 2022   AIC                           -433.168
# Time:                        03:56:25   BIC                           -426.215
# Sample:                             0   HQIC                          -430.366
#                                 - 240
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1          0.3719      0.049      7.629      0.000       0.276       0.467
# sigma2         0.0094      0.000     58.984      0.000       0.009       0.010
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):             86107.25
# Prob(Q):                              0.95   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.15   Skew:                            -7.87
# Prob(H) (two-sided):                  0.53   Kurtosis:                        94.65
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
prediction_log=pd.DataFrame(Arima_model.predict(n_periods=16),index=test.index)
prediction_log.columns=['Predicted_SMA_20']

# %%
prediction_log
# Out:
#             Predicted_SMA_20
# Date
# 2020-01-31          7.142683
# 2020-02-29          7.142683
# 2020-03-31          7.142683
# 2020-04-30          7.142683
# 2020-05-31          7.142683
# 2020-06-30          7.142683
# 2020-07-31          7.142683
# 2020-08-31          7.142683
# 2020-09-30          7.142683
# 2020-10-31          7.142683
# 2020-11-30          7.142683
# 2020-12-31          7.142683
# 2021-01-31          7.142683
# 2021-02-28          7.142683
# 2021-03-31          7.142683
# 2021-04-30          7.142683

# %%
prediction1=np.exp(prediction_log)
prediction1
# Out:
#             Predicted_SMA_20
# Date
# 2020-01-31       1264.817047
# 2020-02-29       1264.817047
# 2020-03-31       1264.817047
# 2020-04-30       1264.817047
# 2020-05-31       1264.817047
# 2020-06-30       1264.817047
# 2020-07-31       1264.817047
# 2020-08-31       1264.817047
# 2020-09-30       1264.817047
# 2020-10-31       1264.817047
# 2020-11-30       1264.817047
# 2020-12-31       1264.817047
# 2021-01-31       1264.817047
# 2021-02-28       1264.817047
# 2021-03-31       1264.817047
# 2021-04-30       1264.817047

# %%
test['log_prediction']=prediction1
test['Error_log']=test['SMA_20']-test['log_prediction']
#test=test.drop(['train_log'],axis=1)
test.head()
# Out:
#                  SMA_20  Predicted_SMA_20       Error  log_prediction  \
# Date
# 2020-01-31  1270.653478        1261.49414    9.159338     1264.817047
# 2020-02-29  1234.681250        1261.49414  -26.812890     1264.817047
# 2020-03-31  1124.135238        1261.49414 -137.358902     1264.817047
# 2020-04-30   896.665833        1261.49414 -364.828307     1264.817047
# 2020-05-31   917.564605        1261.49414 -343.929535     1264.817047
#
#              Error_log
# Date
# 2020-01-31    5.836431
# 2020-02-29  -30.135797
# 2020-03-31 -140.681809
# 2020-04-30 -368.151214
# 2020-05-31 -347.252442

# %% [markdown]
# **STEP6-EVALUATE MODEL PERFORMANCE for SMA_20ARIMA**

# %% [markdown]
# **MEAN ABSOLUTE ERROR (MAE) FOR TEST DATA**

# %%
from sklearn.metrics import mean_absolute_error
print("MEAN ABSOLUTE ERROR (MAE) FOR TEST DATA IS")
np.round(mean_absolute_error(test.SMA_20,prediction1),3)
# Out:
# MEAN ABSOLUTE ERROR (MAE) FOR TEST DATA IS
# 184.172

# %% [markdown]
# **MEAN SQUARE ERROR (MSE) FOR TEST DATA**

# %%
from sklearn.metrics import mean_squared_error
print("MEAN SQUARE ERROR (MSE) FOR TEST DATA IS")
mse=np.round(mean_squared_error(test.SMA_20,prediction1),3)
mse
# Out:
# MEAN SQUARE ERROR (MSE) FOR TEST DATA IS
# 45572.183

# %% [markdown]
# **ROOT MEAN SQUARE ERROR (MSE) FOR TEST DATA**

# %%
import math
math.sqrt(mse)
# Out:
# 213.47642258572725

# %% [markdown]
# **MEDIAN ABSOLUTE ERROR (MAE) FOR TEST DATA**

# %%
from sklearn.metrics import median_absolute_error
print("MEDIAN ABSOLUTE ERROR (MAE) FOR TEST DATA IS")
np.round(median_absolute_error(test.SMA_20,prediction1),3)
# Out:
# MEDIAN ABSOLUTE ERROR (MAE) FOR TEST DATA IS
# 185.137

# %% [markdown]
# **Mean Absolute Percentage Error FOR TEST DATA**

# %%
print("MAPE FOR TEST DATA IS")
mape1 = np.mean(np.abs((test.SMA_20-prediction1)/test.SMA_20))*100
np.round(mape1,3)
# Out:
# MAPE FOR TEST DATA IS
# 2020-01-31 00:00:00   NaN
# 2020-02-29 00:00:00   NaN
# 2020-03-31 00:00:00   NaN
# 2020-04-30 00:00:00   NaN
# 2020-05-31 00:00:00   NaN
# 2020-06-30 00:00:00   NaN
# 2020-07-31 00:00:00   NaN
# 2020-08-31 00:00:00   NaN
# 2020-09-30 00:00:00   NaN
# 2020-10-31 00:00:00   NaN
# 2020-11-30 00:00:00   NaN
# 2020-12-31 00:00:00   NaN
# 2021-01-31 00:00:00   NaN
# 2021-02-28 00:00:00   NaN
# 2021-03-31 00:00:00   NaN
# 2021-04-30 00:00:00   NaN
# Predicted_SMA_20      NaN
# dtype: float64

# %%
test.head()
# Out:
#                  SMA_20  Predicted_SMA_20       Error  log_prediction  \
# Date
# 2020-01-31  1270.653478        1261.49414    9.159338     1264.817047
# 2020-02-29  1234.681250        1261.49414  -26.812890     1264.817047
# 2020-03-31  1124.135238        1261.49414 -137.358902     1264.817047
# 2020-04-30   896.665833        1261.49414 -364.828307     1264.817047
# 2020-05-31   917.564605        1261.49414 -343.929535     1264.817047
#
#              Error_log
# Date
# 2020-01-31    5.836431
# 2020-02-29  -30.135797
# 2020-03-31 -140.681809
# 2020-04-30 -368.151214
# 2020-05-31 -347.252442

# %%
import matplotlib.pyplot as plt
# plot lines
plt.figure(figsize=(12, 6))
plt.title('The close values of HDFCBANK stock equity', fontsize=20)
plt.xlabel('Year', fontsize=16)
plt.ylabel('close values', fontsize=16)
plt.plot(test.index,test['SMA_20'],color='b',linewidth=1.5)
plt.plot(test.index,test['Predicted_SMA_20'],color='g',linewidth=3.5)
plt.plot(test.index,test['log_prediction'],color='r',linewidth=1.5)
plt.legend(labels =['SMA_20', 'Predicted_SMA_20','log_prediction'], fontsize=14)
plt.show()
# Out:
# Text(0.5, 1.0, 'The close values of HDFCBANK stock equity')
# Text(0.5, 0, 'Year')
# Text(0, 0.5, 'close values')

# %%
# !jupyter nbconvert SMA_20ARIMA_StockMarketPrediction.ipynb
# Out:
# [NbConvertApp] Converting notebook SMA_20ARIMA_StockMarketPrediction.ipynb to html
# [NbConvertApp] Writing 1363554 bytes to SMA_20ARIMA_StockMarketPrediction.html
