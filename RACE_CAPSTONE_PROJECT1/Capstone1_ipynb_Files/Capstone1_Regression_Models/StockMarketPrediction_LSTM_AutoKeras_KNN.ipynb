# %%
#Importing the Libraries
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib. pyplot as plt
import matplotlib
import sklearn
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, Activation, Embedding, LSTM, Dropout, advanced_activations
from keras.callbacks import ModelCheckpoint, TensorBoard
from sklearn.model_selection import TimeSeriesSplit
from sklearn.metrics import mean_squared_error, r2_score
import matplotlib. dates as mandates

# %%
from sklearn import linear_model
import keras.backend as K
from keras.callbacks import EarlyStopping
from keras.optimizers import adam_v2
from keras.models import load_model
from keras.layers import LSTM
from keras.utils.vis_utils import plot_model

# %% [markdown]
# **Get the Dataset**

# %%
df=pd.read_csv("HDFCBANK.csv",na_values=None,index_col='Date',parse_dates=True,infer_datetime_format=True)
df=df.drop(['Trades','Deliverable Volume','%Deliverble'],axis=1)
df.head()
df.head()
# Out:
#               Symbol Series  Prev Close    Open    High     Low    Last  \
# Date
# 2000-01-03  HDFCBANK     EQ      157.40  166.00  170.00  166.00  170.00
# 2000-01-04  HDFCBANK     EQ      170.00  182.00  183.45  171.00  174.00
# 2000-01-05  HDFCBANK     EQ      173.80  170.00  173.90  165.00  168.00
# 2000-01-06  HDFCBANK     EQ      166.95  168.00  170.00  165.30  168.95
# 2000-01-07  HDFCBANK     EQ      168.30  162.15  171.00  162.15  170.75
#
#              Close    VWAP  Volume      Turnover
# Date
# 2000-01-03  170.00  169.52   33259  5.638122e+11
# 2000-01-04  173.80  174.99  168710  2.952261e+12
# 2000-01-05  166.95  169.20  159820  2.704094e+12
# 2000-01-06  168.30  168.44   85026  1.432166e+12
# 2000-01-07  168.35  166.79   85144  1.420158e+12

# %% [markdown]
# **Print the shape of Dataframe  and Check for Null Values**

# %%
print("Dataframe Shape: ",df.shape)
print("Null Value Present: ",df.isnull().values.any())
df.info()
# Out:
# Dataframe Shape:  (5306, 11)
# Null Value Present:  False
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 5306 entries, 2000-01-03 to 2021-04-30
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Symbol      5306 non-null   object
#  1   Series      5306 non-null   object
#  2   Prev Close  5306 non-null   float64
#  3   Open        5306 non-null   float64
#  4   High        5306 non-null   float64
#  5   Low         5306 non-null   float64
#  6   Last        5306 non-null   float64
#  7   Close       5306 non-null   float64
#  8   VWAP        5306 non-null   float64
#  9   Volume      5306 non-null   int64
#  10  Turnover    5306 non-null   float64
# dtypes: float64(8), int64(1), object(2)
# memory usage: 497.4+ KB

# %%
df['Volume_lag_1d'] = df['Volume'].shift(1)

# %% [markdown]
# **Set Target Variable and Select the Features**

# %%
features = ['Prev Close','Open','High','Low','Last','VWAP','Volume_lag_1d']
#df['SMA_100'] = df['Close'].rolling(100, min_periods=100).mean()
df.dropna(inplace=True)
output_var = pd.DataFrame(df['Close'])
df[features].info()
output_var.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 5305 entries, 2000-01-04 to 2021-04-30
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Prev Close     5305 non-null   float64
#  1   Open           5305 non-null   float64
#  2   High           5305 non-null   float64
#  3   Low            5305 non-null   float64
#  4   Last           5305 non-null   float64
#  5   VWAP           5305 non-null   float64
#  6   Volume_lag_1d  5305 non-null   float64
# dtypes: float64(7)
# memory usage: 331.6 KB
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 5305 entries, 2000-01-04 to 2021-04-30
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Close   5305 non-null   float64
# dtypes: float64(1)
# memory usage: 82.9 KB

# %% [markdown]
# **Print the shape of Dataframe-Features  and Check for Null Values-Features**

# %%
print("Dataframe Shape: ",df[features].shape)
print("Null Value Present: ",df[features].isnull().values.any())
# Out:
# Dataframe Shape:  (5305, 7)
# Null Value Present:  False

# %%
df[features].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 5305 entries, 2000-01-04 to 2021-04-30
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Prev Close     5305 non-null   float64
#  1   Open           5305 non-null   float64
#  2   High           5305 non-null   float64
#  3   Low            5305 non-null   float64
#  4   Last           5305 non-null   float64
#  5   VWAP           5305 non-null   float64
#  6   Volume_lag_1d  5305 non-null   float64
# dtypes: float64(7)
# memory usage: 331.6 KB

# %% [markdown]
# **Plot the Close Value**

# %%
df['Close'].plot()

# %% [markdown]
# **Scaling**

# %%
scaler = MinMaxScaler()
feature_transform = scaler.fit_transform(df[features])
feature_transform= pd.DataFrame(columns=features, data=feature_transform, index=df.index)
feature_transform.head()
# Out:
#             Prev Close      Open      High       Low      Last      VWAP  \
# Date
# 2000-01-04    0.002747  0.008258  0.006438  0.005841  0.004583  0.005641
# 2000-01-05    0.004329  0.003266  0.002484  0.003338  0.002083  0.003237
# 2000-01-06    0.001478  0.002434  0.000869  0.003463  0.002479  0.002922
# 2000-01-07    0.002040  0.000000  0.001283  0.002149  0.003229  0.002237
# 2000-01-10    0.002060  0.004472  0.004803  0.003338  0.001375  0.002652
#
#             Volume_lag_1d
# Date
# 2000-01-04       0.000320
# 2000-01-05       0.001667
# 2000-01-06       0.001579
# 2000-01-07       0.000835
# 2000-01-10       0.000836

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
plt.subplots(figsize=(10,10))
sns.heatmap(feature_transform.corr(),cmap='RdYlGn',annot=True)
plt.show()

# %% [markdown]
# **Splitting to Training set and Test set**

# %%
timesplit= TimeSeriesSplit(n_splits=10)
for train_index, test_index in timesplit.split(feature_transform):
  X_train, X_test = feature_transform[:len(train_index)], feature_transform[len(train_index): (len(train_index)+len(test_index))]
  y_train, y_test = output_var[:len(train_index)].values.ravel(), output_var[len(train_index): (len(train_index)+len(test_index))].values.ravel()

# %% [markdown]
# **Process the data for LSTM**

# %%
trainX =np.array(X_train)
testX =np.array(X_test)
X_train = trainX.reshape(X_train.shape[0], 1, X_train.shape[1])
X_test = testX.reshape(X_test.shape[0], 1, X_test.shape[1])

# %% [markdown]
# **Building the LSTM Model**

# %%
lstm = Sequential()
lstm.add(LSTM(32, input_shape=(1, trainX.shape[1]), activation='relu', return_sequences=False))
lstm.add(Dense(1))
lstm.compile(loss='mean_squared_error', optimizer='adam')
plot_model(lstm, show_shapes=True, show_layer_names=True)

# %% [markdown]
# **Model Training**

# %%
history=lstm.fit(X_train, y_train, epochs=100, batch_size=8, verbose=1, shuffle=False)
# Out:
# Epoch 1/100
# 603/603 [==============================] - 3s 2ms/step - loss: 1268169.6250
# Epoch 2/100
# 603/603 [==============================] - 1s 2ms/step - loss: 1134356.7500
# Epoch 3/100
# 603/603 [==============================] - 1s 2ms/step - loss: 955562.3750
# Epoch 4/100
# 603/603 [==============================] - 1s 2ms/step - loss: 754080.1875
# Epoch 5/100
# 603/603 [==============================] - 1s 2ms/step - loss: 554471.6250
# Epoch 6/100
# 603/603 [==============================] - 1s 2ms/step - loss: 376284.4062
# Epoch 7/100
# 603/603 [==============================] - 1s 2ms/step - loss: 232594.5000
# Epoch 8/100
# 603/603 [==============================] - 1s 2ms/step - loss: 129375.9922
# Epoch 9/100
# 603/603 [==============================] - 1s 2ms/step - loss: 65129.4805
# Epoch 10/100
# 603/603 [==============================] - 1s 2ms/step - loss: 31454.5566
# Epoch 11/100
# 603/603 [==============================] - 1s 2ms/step - loss: 15823.7100
# Epoch 12/100
# 603/603 [==============================] - 1s 2ms/step - loss: 6935.8799
# Epoch 13/100
# 603/603 [==============================] - 1s 2ms/step - loss: 2138.6128
# Epoch 14/100
# 603/603 [==============================] - 1s 2ms/step - loss: 684.2676
# Epoch 15/100
# 603/603 [==============================] - 1s 2ms/step - loss: 369.5441
# Epoch 16/100
# 603/603 [==============================] - 1s 2ms/step - loss: 78.5811
# Epoch 89/100
# 603/603 [==============================] - 1s 2ms/step - loss: 77.7549
# Epoch 90/100
# 603/603 [==============================] - 1s 2ms/step - loss: 76.9249
# Epoch 91/100
# 603/603 [==============================] - 1s 2ms/step - loss: 76.0909
# Epoch 92/100
# 603/603 [==============================] - 1s 2ms/step - loss: 75.2523
# Epoch 93/100
# 603/603 [==============================] - 1s 2ms/step - loss: 74.4091
# Epoch 94/100
# 603/603 [==============================] - 1s 2ms/step - loss: 73.5610
# Epoch 95/100
# 603/603 [==============================] - 1s 2ms/step - loss: 72.7082
# Epoch 96/100
# 603/603 [==============================] - 1s 2ms/step - loss: 71.8503
# Epoch 97/100
# 603/603 [==============================] - 1s 2ms/step - loss: 70.9877
# Epoch 98/100
# 603/603 [==============================] - 1s 2ms/step - loss: 70.1203
# Epoch 99/100
# 603/603 [==============================] - 1s 2ms/step - loss: 69.2487
# Epoch 100/100
# 603/603 [==============================] - 1s 2ms/step - loss: 68.3731

# %% [markdown]
# **LSTM Prediction**

# %%
y_pred= lstm.predict(X_test)

# %% [markdown]
# **EVALUATE MODEL PERFORMANCE FOR LSTM**

# %% [markdown]
# **MEAN ABSOLUTE ERROR (MAE) FOR TEST DATA**

# %%
from sklearn.metrics import mean_absolute_error
print("MEAN ABSOLUTE ERROR (MAE) FOR TEST DATA IS")
np.round(mean_absolute_error(y_pred,y_test),3)
# Out:
# MEAN ABSOLUTE ERROR (MAE) FOR TEST DATA IS
# 9.705

# %% [markdown]
# **MEAN SQUARE ERROR (MSE) FOR TEST DATA**

# %%
from sklearn.metrics import mean_squared_error
print("MEAN SQUARE ERROR (MSE) FOR TEST DATA IS")
mse=np.round(mean_squared_error(y_pred,y_test),3)
mse
# Out:
# MEAN SQUARE ERROR (MSE) FOR TEST DATA IS
# 159.011

# %% [markdown]
# **ROOT MEAN SQUARE ERROR (MSE) FOR TEST DATA**

# %%
import math
math.sqrt(mse)
# Out:
# 12.609956383746932

# %% [markdown]
# **MEDIAN ABSOLUTE ERROR (MAE) FOR TEST DATA**

# %%
from sklearn.metrics import median_absolute_error
print("MEDIAN ABSOLUTE ERROR (MAE) FOR TEST DATA IS")
np.round(median_absolute_error(y_pred,y_test),3)
# Out:
# MEDIAN ABSOLUTE ERROR (MAE) FOR TEST DATA IS
# 8.204

# %% [markdown]
# **Mean Absolute Percentage Error FOR TEST DATA**

# %%
mape = np.mean(np.abs((y_test - y_pred)/y_test))*100
print("MAPE FOR TEST DATA IS")
np.round(mape,3)
# Out:
# MAPE FOR TEST DATA IS
# 33.401

# %%
#Predicted vs True Adj Close Value – LSTM
plt.plot(y_test, label='True Value')
plt.plot(y_pred, label='LSTM Value')
plt.title("Prediction by LSTM")
plt.xlabel('Time Scale')
plt.ylabel('Scaled USD')
plt.legend()
plt.show()

# %%
#!pip install autokeras

# %%
from autokeras import StructuredDataRegressor
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split

# %%
df[features].head()
# Out:
#             Prev Close    Open    High     Low    Last    VWAP  Volume_lag_1d
# Date
# 2000-01-04      170.00  182.00  183.45  171.00  174.00  174.99        33259.0
# 2000-01-05      173.80  170.00  173.90  165.00  168.00  169.20       168710.0
# 2000-01-06      166.95  168.00  170.00  165.30  168.95  168.44       159820.0
# 2000-01-07      168.30  162.15  171.00  162.15  170.75  166.79        85026.0
# 2000-01-10      168.35  172.90  179.50  165.00  166.30  167.79        85144.0

# %%
# basic data preparation
X = df[features].astype('float32')
y = output_var.astype('float32')

# %%
# separate into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=1)
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (4244, 7) (1061, 7) (4244, 1) (1061, 1)

# %%
# Initialize the StructuredDataRegressor
reg = StructuredDataRegressor(max_trials=15,overwrite=True,metrics=['mae'])
# Search for the best model.
reg.fit(X_train.to_numpy(),y_train.to_numpy(), validation_split=0.2,epochs=100, verbose=0)
# Out:
# /usr/local/lib/python3.7/dist-packages/keras_tuner/engine/metrics_tracking.py:105: RuntimeWarning: All-NaN axis encountered
#   return np.nanmin(values)
# INFO:tensorflow:Oracle triggered exit
# Epoch 1/100
# 133/133 [==============================] - 1s 5ms/step - loss: 1418698.1250 - mae: 1007.2139
# Epoch 2/100
# 133/133 [==============================] - 1s 6ms/step - loss: 1384108.1250 - mae: 993.4410
# Epoch 3/100
# 133/133 [==============================] - 1s 5ms/step - loss: 1210758.0000 - mae: 923.4690
# Epoch 4/100
# 133/133 [==============================] - 1s 5ms/step - loss: 706997.3750 - mae: 704.9417
# Epoch 5/100
# 133/133 [==============================] - 1s 5ms/step - loss: 177807.8125 - mae: 360.3170
# Epoch 6/100
# 133/133 [==============================] - 1s 5ms/step - loss: 33036.9219 - mae: 147.4712
# Epoch 7/100
# 133/133 [==============================] - 1s 5ms/step - loss: 1156.5342 - mae: 20.6409
# Epoch 8/100
# 133/133 [==============================] - 1s 5ms/step - loss: 183.9089 - mae: 8.1743
# Epoch 9/100
# 133/133 [==============================] - 1s 5ms/step - loss: 130.4328 - mae: 7.6395
# Epoch 10/100
# 133/133 [==============================] - 1s 5ms/step - loss: 103.8067 - mae: 6.8972
# Epoch 11/100
# 133/133 [==============================] - 1s 5ms/step - loss: 96.3746 - mae: 6.8476
# Epoch 12/100
# 133/133 [==============================] - 1s 5ms/step - loss: 77.4007 - mae: 6.1132
# Epoch 13/100
# 133/133 [==============================] - 1s 5ms/step - loss: 62.1043 - mae: 5.5421
# Epoch 14/100
# 133/133 [==============================] - 1s 5ms/step - loss: 51.6956 - mae: 5.0075
# Epoch 15/100
# 133/133 [==============================] - 1s 5ms/step - loss: 42.1646 - mae: 4.4397
# Epoch 16/100
# 133/133 [==============================] - 1s 5ms/step - loss: 38.9339 - mae: 4.3109
# Epoch 17/100
# 133/133 [==============================] - 1s 5ms/step - loss: 41.2600 - mae: 4.5293
# Epoch 18/100
# 133/133 [==============================] - 1s 5ms/step - loss: 34.2828 - mae: 4.0728
# Epoch 19/100
# 133/133 [==============================] - 1s 6ms/step - loss: 32.3414 - mae: 3.9970
# Epoch 20/100
# 133/133 [==============================] - 1s 5ms/step - loss: 36.3150 - mae: 4.1867
# Epoch 21/100
# 133/133 [==============================] - 1s 5ms/step - loss: 30.1668 - mae: 3.8416
# Epoch 22/100
# 133/133 [==============================] - 1s 5ms/step - loss: 26.7359 - mae: 3.5926
# Epoch 23/100
# 133/133 [==============================] - 1s 5ms/step - loss: 27.3186 - mae: 3.7277
# Epoch 24/100
# 133/133 [==============================] - 1s 5ms/step - loss: 25.1201 - mae: 3.4266
# Epoch 25/100
# 133/133 [==============================] - 1s 5ms/step - loss: 20.1695 - mae: 3.0804
# 133/133 [==============================] - 1s 6ms/step - loss: 12.6920 - mae: 2.3537
# Epoch 85/100
# 133/133 [==============================] - 1s 6ms/step - loss: 12.3799 - mae: 2.2796
# Epoch 86/100
# 133/133 [==============================] - 1s 6ms/step - loss: 12.4777 - mae: 2.3078
# Epoch 87/100
# 133/133 [==============================] - 1s 6ms/step - loss: 12.2100 - mae: 2.2853
# Epoch 88/100
# 133/133 [==============================] - 1s 5ms/step - loss: 11.8059 - mae: 2.2217
# Epoch 89/100
# 133/133 [==============================] - 1s 5ms/step - loss: 11.5191 - mae: 2.1729
# Epoch 90/100
# 133/133 [==============================] - 1s 6ms/step - loss: 11.5519 - mae: 2.1845
# Epoch 91/100
# 133/133 [==============================] - 1s 6ms/step - loss: 11.1799 - mae: 2.1475
# Epoch 92/100
# 133/133 [==============================] - 1s 5ms/step - loss: 11.0677 - mae: 2.1304
# Epoch 93/100
# 133/133 [==============================] - 1s 5ms/step - loss: 11.0356 - mae: 2.1131
# Epoch 94/100
# 133/133 [==============================] - 1s 5ms/step - loss: 11.6591 - mae: 2.2069
# Epoch 95/100
# 133/133 [==============================] - 1s 6ms/step - loss: 11.1843 - mae: 2.1361
# Epoch 96/100
# 133/133 [==============================] - 1s 5ms/step - loss: 10.9223 - mae: 2.0805
# Epoch 97/100
# 133/133 [==============================] - 1s 6ms/step - loss: 10.7835 - mae: 2.0459
# Epoch 98/100
# 133/133 [==============================] - 1s 5ms/step - loss: 10.5609 - mae: 2.0159
# Epoch 99/100
# 133/133 [==============================] - 1s 5ms/step - loss: 10.4066 - mae: 1.9942
# Epoch 100/100
# 133/133 [==============================] - 1s 6ms/step - loss: 10.3465 - mae: 1.9834
# INFO:tensorflow:Assets written to: ./structured_data_regressor/best_model/assets

# %%
# evaluate the model
loss, acc =reg.evaluate(X_train,y_train, verbose=0)
print('Accuracy: %.3f' % acc)
print('loss: %.3f' % loss)
# Out:
# Accuracy: 1.983
# loss: 10.345

# %%
y_predict= reg.predict(X_test)
# Out:
# 34/34 [==============================] - 0s 2ms/step

# %% [markdown]
# **EVALUATE MODEL PERFORMANCE for Autokeras**

# %% [markdown]
# **MEAN ABSOLUTE ERROR (MAE) FOR TEST DATA**

# %%
from sklearn.metrics import mean_absolute_error
print("MEAN ABSOLUTE ERROR (MAE) FOR TEST DATA IS")
np.round(mean_absolute_error(y_predict,y_test),3)
# Out:
# MEAN ABSOLUTE ERROR (MAE) FOR TEST DATA IS
# 2.59

# %% [markdown]
# **MEAN SQUARE ERROR (MSE) FOR TEST DATA**

# %%
from sklearn.metrics import mean_squared_error
print("MEAN SQUARE ERROR (MSE) FOR TEST DATA IS")
mse=np.round(mean_squared_error(y_predict,y_test),3)
mse
# Out:
# MEAN SQUARE ERROR (MSE) FOR TEST DATA IS
# 242.513

# %% [markdown]
# **ROOT MEAN SQUARE ERROR (MSE) FOR TEST DATA**

# %%
import math
math.sqrt(mse)
# Out:
# 15.572828917325241

# %% [markdown]
# **MEDIAN ABSOLUTE ERROR (MAE) FOR TEST DATA**

# %%
from sklearn.metrics import median_absolute_error
print("MEDIAN ABSOLUTE ERROR (MAE) FOR TEST DATA IS")
np.round(median_absolute_error(y_predict,y_test),3)
# Out:
# MEDIAN ABSOLUTE ERROR (MAE) FOR TEST DATA IS
# 1.102

# %% [markdown]
# **Mean Absolute Percentage Error FOR TEST DATA**

# %%
mape = np.mean(np.abs((y_test - y_predict)/y_test))*100
print("MAPE FOR TEST DATA IS")
np.round(mape,3)
# Out:
# MAPE FOR TEST DATA IS
# Close    0.27
# dtype: float32

# %%
import random
import math
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error 
from sklearn.neighbors import KNeighborsRegressor
from sklearn.linear_model import LinearRegression
import numpy as np
import pandas as pd
import sklearn
import seaborn as sns
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
# %matplotlib inline
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
all_data = pd.read_csv("HDFCBANK.csv")
all_data=all_data.drop(['Date','Trades','Deliverable Volume','%Deliverble','Symbol','Series'],axis=1)
all_data.head()
all_data.info()
# Out:
#    Prev Close    Open    High     Low    Last   Close    VWAP  Volume  \
# 0      157.40  166.00  170.00  166.00  170.00  170.00  169.52   33259
# 1      170.00  182.00  183.45  171.00  174.00  173.80  174.99  168710
# 2      173.80  170.00  173.90  165.00  168.00  166.95  169.20  159820
# 3      166.95  168.00  170.00  165.30  168.95  168.30  168.44   85026
# 4      168.30  162.15  171.00  162.15  170.75  168.35  166.79   85144
#
#        Turnover
# 0  5.638122e+11
# 1  2.952261e+12
# 2  2.704094e+12
# 3  1.432166e+12
# 4  1.420158e+12
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5306 entries, 0 to 5305
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Prev Close  5306 non-null   float64
#  1   Open        5306 non-null   float64
#  2   High        5306 non-null   float64
#  3   Low         5306 non-null   float64
#  4   Last        5306 non-null   float64
#  5   Close       5306 non-null   float64
#  6   VWAP        5306 non-null   float64
#  7   Volume      5306 non-null   int64
#  8   Turnover    5306 non-null   float64
# dtypes: float64(8), int64(1)
# memory usage: 373.2 KB

# %%
all_data['Volume_lag_1d'] = all_data['Volume'].shift(1)
all_data.dropna(inplace=True)
x=all_data.drop(['Close','Turnover','Volume'],axis=1)
x.head()
x.info()
# Out:
#    Prev Close    Open    High     Low    Last    VWAP  Volume_lag_1d
# 1      170.00  182.00  183.45  171.00  174.00  174.99        33259.0
# 2      173.80  170.00  173.90  165.00  168.00  169.20       168710.0
# 3      166.95  168.00  170.00  165.30  168.95  168.44       159820.0
# 4      168.30  162.15  171.00  162.15  170.75  166.79        85026.0
# 5      168.35  172.90  179.50  165.00  166.30  167.79        85144.0
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5305 entries, 1 to 5305
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Prev Close     5305 non-null   float64
#  1   Open           5305 non-null   float64
#  2   High           5305 non-null   float64
#  3   Low            5305 non-null   float64
#  4   Last           5305 non-null   float64
#  5   VWAP           5305 non-null   float64
#  6   Volume_lag_1d  5305 non-null   float64
# dtypes: float64(7)
# memory usage: 331.6 KB

# %%
y=all_data['Close']
y.head()
y.shape
# Out:
# 1    173.80
# 2    166.95
# 3    168.30
# 4    168.35
# 5    165.90
# Name: Close, dtype: float64
# (5305,)

# %%
import sklearn
from sklearn.preprocessing import MinMaxScaler
scld=MinMaxScaler(feature_range=(0,1))
arr_scld=scld.fit_transform(x)
x_scld=pd.DataFrame(arr_scld,columns=x.columns)
x_scld.head()
x_scld.describe()
# Out:
#    Prev Close      Open      High       Low      Last      VWAP  Volume_lag_1d
# 0    0.002747  0.008258  0.006438  0.005841  0.004583  0.005641       0.000320
# 1    0.004329  0.003266  0.002484  0.003338  0.002083  0.003237       0.001667
# 2    0.001478  0.002434  0.000869  0.003463  0.002479  0.002922       0.001579
# 3    0.002040  0.000000  0.001283  0.002149  0.003229  0.002237       0.000835
# 4    0.002060  0.004472  0.004803  0.003338  0.001375  0.002652       0.000836
#         Prev Close         Open         High          Low         Last  \
# count  5305.000000  5305.000000  5305.000000  5305.000000  5305.000000
# mean      0.351255     0.351720     0.352839     0.349221     0.351884
# std       0.264615     0.264333     0.265546     0.262636     0.264866
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.131764     0.133369     0.132090     0.132015     0.132500
# 50%       0.321179     0.323460     0.325453     0.319272     0.322167
# 75%       0.523539     0.524929     0.526662     0.518213     0.525000
# max       1.000000     1.000000     1.000000     1.000000     1.000000
#
#               VWAP  Volume_lag_1d
# count  5305.000000    5305.000000
# mean      0.351009       0.020868
# std       0.263744       0.039425
# min       0.000000       0.000000
# 25%       0.132300       0.003030
# 50%       0.322114       0.009380
# 75%       0.522716       0.021086
# max       1.000000       1.000000

# %%
train_x,test_x,train_y,test_y=train_test_split(x_scld,y,test_size=0.20,random_state=1)
train_x.shape
test_x.shape
train_y.shape
test_y.shape
# Out:
# (4244, 7)
# (1061, 7)
# (4244,)
# (1061,)

# %%
model = KNeighborsRegressor(n_neighbors=8)

# %%
model.fit(train_x,train_y)
# Out:
# KNeighborsRegressor(n_neighbors=8)

# %%
predicted_values=model.predict(test_x)
predicted_values
# Out:
# array([1162.525  , 1789.85625, 1243.64375, ...,  238.7125 ,  930.8    ,
#         679.43125])

# %% [markdown]
# **STEP6-EVALUATE MODEL PERFORMANCE for KNeighborsRegressor**

# %% [markdown]
# **MEAN ABSOLUTE ERROR (MAE) FOR TEST DATA**

# %%
from sklearn.metrics import mean_absolute_error
print("MEAN ABSOLUTE ERROR (MAE) FOR TEST DATA IS")
np.round(mean_absolute_error(predicted_values,test_y),3)
# Out:
# MEAN ABSOLUTE ERROR (MAE) FOR TEST DATA IS
# 5.423

# %% [markdown]
# **MEAN SQUARE ERROR (MSE) FOR TEST DATA**

# %%
from sklearn.metrics import mean_squared_error
print("MEAN SQUARE ERROR (MSE) FOR TEST DATA IS")
mse=np.round(mean_squared_error(predicted_values,test_y),3)
mse
# Out:
# MEAN SQUARE ERROR (MSE) FOR TEST DATA IS
# 132.075

# %% [markdown]
# **ROOT MEAN SQUARE ERROR (MSE) FOR TEST DATA**

# %%
import math
math.sqrt(mse)
# Out:
# 11.492388785626773

# %% [markdown]
# **MEDIAN ABSOLUTE ERROR (MAE) FOR TEST DATA**

# %%
from sklearn.metrics import median_absolute_error
print("MEDIAN ABSOLUTE ERROR (MAE) FOR TEST DATA IS")
np.round(median_absolute_error(predicted_values,test_y),3)
# Out:
# MEDIAN ABSOLUTE ERROR (MAE) FOR TEST DATA IS
# 3.163

# %% [markdown]
# **Mean Absolute Percentage Error FOR TEST DATA**

# %%
mape = np.mean(np.abs((test_y - predicted_values)/test_y))*100
print("MAPE FOR TEST DATA IS")
np.round(mape,3)
# Out:
# MAPE FOR TEST DATA IS
# 0.593

# %%
# !jupyter nbconvert StockMarketPrediction_LSTM_AutoKeras_KNN.ipynb
# Out:
# [NbConvertApp] Converting notebook StockMarketPrediction_LSTM_AutoKeras_KNN.ipynb to html
# [NbConvertApp] Writing 494135 bytes to StockMarketPrediction_LSTM_AutoKeras_KNN.html
