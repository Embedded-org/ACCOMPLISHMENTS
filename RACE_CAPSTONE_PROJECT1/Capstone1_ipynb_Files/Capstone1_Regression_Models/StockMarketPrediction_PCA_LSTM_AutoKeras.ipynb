# %%
#Importing the Libraries
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib. pyplot as plt
import matplotlib
import sklearn
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, Activation, Embedding, LSTM, Dropout, advanced_activations
from keras.callbacks import ModelCheckpoint, TensorBoard
from sklearn.model_selection import TimeSeriesSplit
from sklearn.metrics import mean_squared_error, r2_score
import matplotlib. dates as mandates

# %%
from sklearn import linear_model
import keras.backend as K
from keras.callbacks import EarlyStopping
from keras.optimizers import adam_v2
from keras.models import load_model
from keras.layers import LSTM
from keras.utils.vis_utils import plot_model

# %% [markdown]
# **Get the Dataset**

# %%
df=pd.read_csv("HDFCBANK.csv",na_values=None,index_col='Date',parse_dates=True,infer_datetime_format=True)
df=df.drop(['Trades','Deliverable Volume','%Deliverble'],axis=1)
df.head()
# Out:
#               Symbol Series  Prev Close    Open    High     Low    Last  \
# Date
# 2000-01-03  HDFCBANK     EQ      157.40  166.00  170.00  166.00  170.00
# 2000-01-04  HDFCBANK     EQ      170.00  182.00  183.45  171.00  174.00
# 2000-01-05  HDFCBANK     EQ      173.80  170.00  173.90  165.00  168.00
# 2000-01-06  HDFCBANK     EQ      166.95  168.00  170.00  165.30  168.95
# 2000-01-07  HDFCBANK     EQ      168.30  162.15  171.00  162.15  170.75
#
#              Close    VWAP  Volume      Turnover
# Date
# 2000-01-03  170.00  169.52   33259  5.638122e+11
# 2000-01-04  173.80  174.99  168710  2.952261e+12
# 2000-01-05  166.95  169.20  159820  2.704094e+12
# 2000-01-06  168.30  168.44   85026  1.432166e+12
# 2000-01-07  168.35  166.79   85144  1.420158e+12

# %% [markdown]
# **Print the shape of Dataframe  and Check for Null Values**

# %%
print("Dataframe Shape: ",df.shape)
print("Null Value Present: ",df.isnull().values.any())
df.info()
# Out:
# Dataframe Shape:  (5306, 11)
# Null Value Present:  False
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 5306 entries, 2000-01-03 to 2021-04-30
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Symbol      5306 non-null   object
#  1   Series      5306 non-null   object
#  2   Prev Close  5306 non-null   float64
#  3   Open        5306 non-null   float64
#  4   High        5306 non-null   float64
#  5   Low         5306 non-null   float64
#  6   Last        5306 non-null   float64
#  7   Close       5306 non-null   float64
#  8   VWAP        5306 non-null   float64
#  9   Volume      5306 non-null   int64
#  10  Turnover    5306 non-null   float64
# dtypes: float64(8), int64(1), object(2)
# memory usage: 497.4+ KB

# %%
df['Volume_lag_1d'] = df['Volume'].shift(1)

# %% [markdown]
# **Set Target Variable and Select the Features**

# %%
features = ['Prev Close','Open','High','Low','Last','VWAP','Volume_lag_1d']
#df['SMA_100'] = df['Close'].rolling(100, min_periods=100).mean()
df.dropna(inplace=True)
output_var = pd.DataFrame(df['Close'])
df[features].info()
output_var.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 5305 entries, 2000-01-04 to 2021-04-30
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Prev Close     5305 non-null   float64
#  1   Open           5305 non-null   float64
#  2   High           5305 non-null   float64
#  3   Low            5305 non-null   float64
#  4   Last           5305 non-null   float64
#  5   VWAP           5305 non-null   float64
#  6   Volume_lag_1d  5305 non-null   float64
# dtypes: float64(7)
# memory usage: 331.6 KB
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 5305 entries, 2000-01-04 to 2021-04-30
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Close   5305 non-null   float64
# dtypes: float64(1)
# memory usage: 82.9 KB

# %% [markdown]
# **Print the shape of Dataframe-Features  and Check for Null Values-Features**

# %%
print("Dataframe Shape: ",df[features].shape)
print("Null Value Present: ",df[features].isnull().values.any())
# Out:
# Dataframe Shape:  (5305, 7)
# Null Value Present:  False

# %%
df[features].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 5305 entries, 2000-01-04 to 2021-04-30
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Prev Close     5305 non-null   float64
#  1   Open           5305 non-null   float64
#  2   High           5305 non-null   float64
#  3   Low            5305 non-null   float64
#  4   Last           5305 non-null   float64
#  5   VWAP           5305 non-null   float64
#  6   Volume_lag_1d  5305 non-null   float64
# dtypes: float64(7)
# memory usage: 331.6 KB

# %% [markdown]
# **Plot the Close Value**

# %%
df['Close'].plot()

# %% [markdown]
# **Scaling**

# %%
scaler = MinMaxScaler()
feature_transform = scaler.fit_transform(df[features])
feature_transform= pd.DataFrame(columns=features, data=feature_transform, index=df.index)
feature_transform.head()
# Out:
#             Prev Close      Open      High       Low      Last      VWAP  \
# Date
# 2000-01-04    0.002747  0.008258  0.006438  0.005841  0.004583  0.005641
# 2000-01-05    0.004329  0.003266  0.002484  0.003338  0.002083  0.003237
# 2000-01-06    0.001478  0.002434  0.000869  0.003463  0.002479  0.002922
# 2000-01-07    0.002040  0.000000  0.001283  0.002149  0.003229  0.002237
# 2000-01-10    0.002060  0.004472  0.004803  0.003338  0.001375  0.002652
#
#             Volume_lag_1d
# Date
# 2000-01-04       0.000320
# 2000-01-05       0.001667
# 2000-01-06       0.001579
# 2000-01-07       0.000835
# 2000-01-10       0.000836

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
plt.subplots(figsize=(10,10))
sns.heatmap(feature_transform.corr(),cmap='RdYlGn',annot=True)
plt.show()

# %% [markdown]
# **FIT PCA MODEL,THE NUMBER OF COMPONENTS WILL BE SAME AS NUMBER OF VARIABLES**

# %%
from sklearn.decomposition import PCA
pca=PCA().fit(feature_transform[features])
pca
# Out:
# PCA()

# %%
str(pca.explained_variance_ratio_.sum())
# Out:
# '1.0'

# %%
str(pca.explained_variance_ratio_)
# Out:
# '[9.95755711e-01 3.63148311e-03 4.15370876e-04 9.53678800e-05\n 8.08067886e-05 1.49292113e-05 6.33139389e-06]'

# %% [markdown]
# **FIT PCA MODEL,THE NUMBER OF COMPONENTS WILL BE 5 FOR WHICH THE EXPLAINED VARIANCE RATIO.SUM WILL BE 99.99%**

# %%
pca=PCA(5).fit(feature_transform)

# %%
str(pca.explained_variance_ratio_.sum())
# Out:
# '0.9999787393948255'

# %%
str(pca.explained_variance_ratio_)
# Out:
# '[9.95755711e-01 3.63148311e-03 4.15370876e-04 9.53678800e-05\n 8.08067886e-05]'

# %%
pca.explained_variance_
# Out:
# array([4.18868680e-01, 1.52759811e-03, 1.74727444e-04, 4.01168856e-05,
#        3.39917035e-05])

# %%
pca_df=pd.DataFrame(pca.components_,columns=df[features].columns)
pca_df
# Out:
#    Prev Close      Open      High       Low      Last      VWAP  Volume_lag_1d
# 0    0.408441  0.408354  0.410221  0.405723  0.409175  0.407482       0.008034
# 1   -0.005728 -0.001642  0.004788 -0.011929 -0.001409 -0.003854       0.999891
# 2    0.904925 -0.074710 -0.191439 -0.180450 -0.252474 -0.206318       0.002674
# 3    0.059523 -0.353937  0.596831 -0.657374  0.279383  0.068384      -0.010283
# 4    0.102593 -0.704926 -0.363657  0.287262  0.491621  0.189899       0.006023

# %%
feature_transform.shape
# Out:
# (5305, 7)

# %%
#transformed features,instead of having 8,we have 5 now.this can now be plugged into any further modelling work
x_scaled_transf=pca.fit_transform(feature_transform)

# %%
x_scaled_transf=pd.DataFrame(x_scaled_transf,columns=('P1','P2','P3','P4','P5'))
x_scaled_transf.shape
# Out:
# (5305, 5)

# %%
x_scaled_transf.head()
# Out:
#          P1        P2        P3        P4        P5
# 0 -0.847020 -0.013728 -0.002550 -0.000630 -0.002757
# 1 -0.853042 -0.012358  0.001593 -0.000360 -0.000034
# 2 -0.855125 -0.012437 -0.000673 -0.001191  0.001017
# 3 -0.856231 -0.013161  0.000125  0.000985  0.002496
# 4 -0.853060 -0.013163 -0.000696  0.000232 -0.002425

# %%
correlation=x_scaled_transf.corr()
correlation
# Out:
#               P1            P2            P3            P4            P5
# P1  1.000000e+00 -2.740546e-16 -3.777150e-17 -3.203888e-17 -1.256809e-17
# P2 -2.740546e-16  1.000000e+00  2.635884e-16  1.352135e-16 -3.292167e-17
# P3 -3.777150e-17  2.635884e-16  1.000000e+00  1.452407e-16 -1.427657e-16
# P4 -3.203888e-17  1.352135e-16  1.452407e-16  1.000000e+00  2.842219e-16
# P5 -1.256809e-17 -3.292167e-17 -1.427657e-16  2.842219e-16  1.000000e+00

# %%
sns.heatmap(correlation,cmap="RdYlGn",annot=True)
plt.show()

# %%
feature_transform=x_scaled_transf
feature_transform['Date'] = df.index
feature_transform = feature_transform.set_index('Date')
feature_transform.head()
# Out:
#                   P1        P2        P3        P4        P5
# Date
# 2000-01-04 -0.847020 -0.013728 -0.002550 -0.000630 -0.002757
# 2000-01-05 -0.853042 -0.012358  0.001593 -0.000360 -0.000034
# 2000-01-06 -0.855125 -0.012437 -0.000673 -0.001191  0.001017
# 2000-01-07 -0.856231 -0.013161  0.000125  0.000985  0.002496
# 2000-01-10 -0.853060 -0.013163 -0.000696  0.000232 -0.002425

# %% [markdown]
# **Splitting to Training set and Test set**

# %%
timesplit= TimeSeriesSplit(n_splits=10)
for train_index, test_index in timesplit.split(feature_transform):
  X_train, X_test = feature_transform[:len(train_index)], feature_transform[len(train_index): (len(train_index)+len(test_index))]
  y_train, y_test = output_var[:len(train_index)].values.ravel(), output_var[len(train_index): (len(train_index)+len(test_index))].values.ravel()

# %% [markdown]
# **Process the data for LSTM**

# %%
trainX =np.array(X_train)
testX =np.array(X_test)
X_train = trainX.reshape(X_train.shape[0], 1, X_train.shape[1])
X_test = testX.reshape(X_test.shape[0], 1, X_test.shape[1])

# %% [markdown]
# **Building the LSTM Model**

# %%
lstm = Sequential()
lstm.add(LSTM(32, input_shape=(1, trainX.shape[1]), activation='relu', return_sequences=False))
lstm.add(Dense(1))
lstm.compile(loss='mean_squared_error', optimizer='adam')
plot_model(lstm, show_shapes=True, show_layer_names=True)

# %% [markdown]
# **Model Training**

# %%
history=lstm.fit(X_train, y_train, epochs=100, batch_size=8, verbose=1, shuffle=False)
# Out:
# Epoch 1/100
# 603/603 [==============================] - 6s 5ms/step - loss: 1329941.7500
# Epoch 2/100
# 603/603 [==============================] - 3s 5ms/step - loss: 1262291.2500
# Epoch 3/100
# 603/603 [==============================] - 3s 5ms/step - loss: 1136180.0000
# Epoch 4/100
# 603/603 [==============================] - 3s 4ms/step - loss: 980366.6250
# Epoch 5/100
# 603/603 [==============================] - 2s 3ms/step - loss: 815796.0625
# Epoch 6/100
# 603/603 [==============================] - 2s 3ms/step - loss: 654649.8750
# Epoch 7/100
# 603/603 [==============================] - 2s 3ms/step - loss: 505380.1875
# Epoch 8/100
# 603/603 [==============================] - 2s 3ms/step - loss: 376091.8750
# Epoch 9/100
# 603/603 [==============================] - 2s 3ms/step - loss: 270097.7500
# Epoch 10/100
# 603/603 [==============================] - 2s 3ms/step - loss: 187675.1562
# Epoch 11/100
# 603/603 [==============================] - 2s 3ms/step - loss: 126516.7734
# Epoch 12/100
# 603/603 [==============================] - 2s 3ms/step - loss: 82069.5938
# Epoch 13/100
# 603/603 [==============================] - 2s 3ms/step - loss: 49022.6250
# Epoch 14/100
# 603/603 [==============================] - 2s 3ms/step - loss: 25160.9082
# Epoch 15/100
# 603/603 [==============================] - 2s 3ms/step - loss: 11302.7246
# Epoch 16/100
# 603/603 [==============================] - 2s 3ms/step - loss: 5451.5171
# Epoch 17/100
# 603/603 [==============================] - 2s 3ms/step - loss: 3482.7966
# Epoch 18/100
# 603/603 [==============================] - 2s 3ms/step - loss: 2697.3594
# Epoch 19/100
# 603/603 [==============================] - 2s 3ms/step - loss: 2144.8015
# Epoch 20/100
# 603/603 [==============================] - 2s 3ms/step - loss: 1675.9027
# Epoch 21/100
# 603/603 [==============================] - 2s 3ms/step - loss: 1301.2048
# Epoch 22/100
# 603/603 [==============================] - 2s 3ms/step - loss: 1020.2725
# Epoch 23/100
# 603/603 [==============================] - 2s 3ms/step - loss: 818.0439
# Epoch 24/100
# 603/603 [==============================] - 1s 2ms/step - loss: 675.8542
# Epoch 25/100
# 603/603 [==============================] - 1s 2ms/step - loss: 576.4752
# Epoch 26/100
# 603/603 [==============================] - 2s 3ms/step - loss: 506.1019
# Epoch 27/100
# 603/603 [==============================] - 2s 3ms/step - loss: 454.7303
# Epoch 28/100
# 603/603 [==============================] - 1s 2ms/step - loss: 415.5960
# Epoch 29/100
# 603/603 [==============================] - 1s 2ms/step - loss: 384.3268
# Epoch 30/100
# 603/603 [==============================] - 1s 2ms/step - loss: 358.1937
# Epoch 31/100
# 603/603 [==============================] - 1s 2ms/step - loss: 335.5344
# Epoch 32/100
# 603/603 [==============================] - 2s 2ms/step - loss: 315.3535
# Epoch 33/100
# 603/603 [==============================] - 1s 2ms/step - loss: 297.0443
# Epoch 34/100
# 603/603 [==============================] - 1s 2ms/step - loss: 280.2339
# Epoch 35/100
# 603/603 [==============================] - 1s 2ms/step - loss: 264.6752
# Epoch 36/100
# 603/603 [==============================] - 1s 2ms/step - loss: 250.2019
# Epoch 37/100
# 603/603 [==============================] - 2s 2ms/step - loss: 236.6958
# Epoch 38/100
# 603/603 [==============================] - 2s 3ms/step - loss: 224.0694
# Epoch 39/100
# 603/603 [==============================] - 1s 2ms/step - loss: 212.2537
# Epoch 40/100
# 603/603 [==============================] - 1s 2ms/step - loss: 201.1911
# Epoch 41/100
# 603/603 [==============================] - 1s 2ms/step - loss: 190.8323
# Epoch 42/100
# 603/603 [==============================] - 1s 2ms/step - loss: 181.1325
# Epoch 43/100
# 603/603 [==============================] - 2s 3ms/step - loss: 172.0486
# Epoch 44/100
# 603/603 [==============================] - 2s 2ms/step - loss: 163.5410
# Epoch 45/100
# 603/603 [==============================] - 2s 2ms/step - loss: 155.5729
# Epoch 46/100
# 603/603 [==============================] - 2s 2ms/step - loss: 148.1071
# Epoch 47/100
# 603/603 [==============================] - 2s 3ms/step - loss: 141.1105
# Epoch 48/100
# 603/603 [==============================] - 1s 2ms/step - loss: 134.5520
# Epoch 49/100
# 603/603 [==============================] - 2s 3ms/step - loss: 128.4019
# Epoch 50/100
# 603/603 [==============================] - 1s 2ms/step - loss: 122.6327
# Epoch 51/100
# 603/603 [==============================] - 1s 2ms/step - loss: 117.2196
# Epoch 52/100
# 603/603 [==============================] - 2s 3ms/step - loss: 112.1387
# Epoch 53/100
# 603/603 [==============================] - 2s 3ms/step - loss: 107.3662
# Epoch 54/100
# 603/603 [==============================] - 2s 3ms/step - loss: 102.8809
# Epoch 55/100
# 603/603 [==============================] - 2s 3ms/step - loss: 98.6578
# Epoch 56/100
# 603/603 [==============================] - 2s 3ms/step - loss: 94.6751
# Epoch 57/100
# 603/603 [==============================] - 2s 3ms/step - loss: 90.9120
# Epoch 58/100
# 603/603 [==============================] - 2s 3ms/step - loss: 87.3513
# Epoch 59/100
# 603/603 [==============================] - 2s 4ms/step - loss: 83.9772
# Epoch 60/100
# 603/603 [==============================] - 2s 3ms/step - loss: 80.7748
# Epoch 61/100
# 603/603 [==============================] - 2s 3ms/step - loss: 77.7319
# Epoch 62/100
# 603/603 [==============================] - 2s 3ms/step - loss: 74.8385
# Epoch 63/100
# 603/603 [==============================] - 1s 2ms/step - loss: 72.0845
# Epoch 64/100
# 603/603 [==============================] - 1s 2ms/step - loss: 69.4615
# Epoch 65/100
# 603/603 [==============================] - 1s 2ms/step - loss: 66.9619
# Epoch 66/100
# 603/603 [==============================] - 2s 2ms/step - loss: 64.5787
# Epoch 67/100
# 603/603 [==============================] - 2s 3ms/step - loss: 62.3056
# Epoch 68/100
# 603/603 [==============================] - 2s 3ms/step - loss: 60.1375
# Epoch 69/100
# 603/603 [==============================] - 2s 2ms/step - loss: 58.0688
# Epoch 70/100
# 603/603 [==============================] - 2s 4ms/step - loss: 56.0954
# Epoch 71/100
# 603/603 [==============================] - 2s 3ms/step - loss: 54.2126
# Epoch 72/100
# 603/603 [==============================] - 2s 3ms/step - loss: 52.4172
# Epoch 73/100
# 603/603 [==============================] - 2s 3ms/step - loss: 50.7053
# Epoch 74/100
# 603/603 [==============================] - 2s 3ms/step - loss: 49.0740
# Epoch 75/100
# 603/603 [==============================] - 2s 3ms/step - loss: 47.5198
# Epoch 76/100
# 603/603 [==============================] - 2s 3ms/step - loss: 46.0401
# Epoch 77/100
# 603/603 [==============================] - 2s 3ms/step - loss: 44.6318
# Epoch 78/100
# 603/603 [==============================] - 2s 3ms/step - loss: 43.2925
# Epoch 79/100
# 603/603 [==============================] - 2s 3ms/step - loss: 42.0194
# Epoch 80/100
# 603/603 [==============================] - 2s 3ms/step - loss: 40.8098
# Epoch 81/100
# 603/603 [==============================] - 1s 2ms/step - loss: 39.6610
# Epoch 82/100
# 603/603 [==============================] - 1s 2ms/step - loss: 38.5703
# Epoch 83/100
# 603/603 [==============================] - 1s 2ms/step - loss: 37.5350
# Epoch 84/100
# 603/603 [==============================] - 1s 2ms/step - loss: 36.5527
# Epoch 85/100
# 603/603 [==============================] - 2s 3ms/step - loss: 35.6202
# Epoch 86/100
# 603/603 [==============================] - 2s 3ms/step - loss: 34.7355
# Epoch 87/100
# 603/603 [==============================] - 2s 3ms/step - loss: 33.8959
# Epoch 88/100
# 603/603 [==============================] - 2s 3ms/step - loss: 33.0987
# Epoch 89/100
# 603/603 [==============================] - 1s 2ms/step - loss: 32.3418
# Epoch 90/100
# 603/603 [==============================] - 2s 3ms/step - loss: 31.6229
# Epoch 91/100
# 603/603 [==============================] - 1s 2ms/step - loss: 30.9401
# Epoch 92/100
# 603/603 [==============================] - 2s 3ms/step - loss: 30.2913
# Epoch 93/100
# 603/603 [==============================] - 2s 3ms/step - loss: 29.6751
# Epoch 94/100
# 603/603 [==============================] - 2s 3ms/step - loss: 29.0897
# Epoch 95/100
# 603/603 [==============================] - 2s 3ms/step - loss: 28.5335
# Epoch 96/100
# 603/603 [==============================] - 2s 3ms/step - loss: 28.0053
# Epoch 97/100
# 603/603 [==============================] - 2s 3ms/step - loss: 27.5038
# Epoch 98/100
# 603/603 [==============================] - 2s 3ms/step - loss: 27.0280
# Epoch 99/100
# 603/603 [==============================] - 2s 3ms/step - loss: 26.5765
# Epoch 100/100
# 603/603 [==============================] - 2s 3ms/step - loss: 26.1483

# %% [markdown]
# **LSTM Prediction**

# %%
y_pred= lstm.predict(X_test)

# %% [markdown]
# **EVALUATE MODEL PERFORMANCE FOR LSTM**

# %% [markdown]
# **MEAN ABSOLUTE ERROR (MAE) FOR TEST DATA**

# %%
from sklearn.metrics import mean_absolute_error
print("MEAN ABSOLUTE ERROR (MAE) FOR TEST DATA IS")
np.round(mean_absolute_error(y_pred,y_test),3)
# Out:
# MEAN ABSOLUTE ERROR (MAE) FOR TEST DATA IS
# 4.366

# %% [markdown]
# **MEAN SQUARE ERROR (MSE) FOR TEST DATA**

# %%
from sklearn.metrics import mean_squared_error
print("MEAN SQUARE ERROR (MSE) FOR TEST DATA IS")
mse=np.round(mean_squared_error(y_pred,y_test),3)
mse
# Out:
# MEAN SQUARE ERROR (MSE) FOR TEST DATA IS
# 34.702

# %% [markdown]
# **ROOT MEAN SQUARE ERROR (MSE) FOR TEST DATA**

# %%
import math
math.sqrt(mse)
# Out:
# 5.890840347522584

# %% [markdown]
# **MEDIAN ABSOLUTE ERROR (MAE) FOR TEST DATA**

# %%
from sklearn.metrics import median_absolute_error
print("MEDIAN ABSOLUTE ERROR (MAE) FOR TEST DATA IS")
np.round(median_absolute_error(y_pred,y_test),3)
# Out:
# MEDIAN ABSOLUTE ERROR (MAE) FOR TEST DATA IS
# 3.597

# %% [markdown]
# **Mean Absolute Percentage Error FOR TEST DATA**

# %%
mape = np.mean(np.abs((y_test - y_pred)/y_test))*100
print("MAPE FOR TEST DATA IS")
np.round(mape,3)
# Out:
# MAPE FOR TEST DATA IS
# 33.435

# %%
#Predicted vs True Adj Close Value – LSTM
plt.plot(y_test, label='True Value')
plt.plot(y_pred, label='LSTM Value')
plt.title("Prediction by LSTM")
plt.xlabel('Time Scale')
plt.ylabel('Scaled USD')
plt.legend()
plt.show()

# %%
x_scaled_transf.head()
# Out:
#          P1        P2        P3        P4        P5       Date
# 0 -0.847020 -0.013728 -0.002550 -0.000630 -0.002757 2000-01-04
# 1 -0.853042 -0.012358  0.001593 -0.000360 -0.000034 2000-01-05
# 2 -0.855125 -0.012437 -0.000673 -0.001191  0.001017 2000-01-06
# 3 -0.856231 -0.013161  0.000125  0.000985  0.002496 2000-01-07
# 4 -0.853060 -0.013163 -0.000696  0.000232 -0.002425 2000-01-10

# %%
#!pip install autokeras

# %%
print(x_scaled_transf.shape)
x_scaled_transf=x_scaled_transf.drop(['Date'],axis=1)
# Out:
# (5305, 6)

# %%
x_scaled_transf.head()
# Out:
#          P1        P2        P3        P4        P5
# 0 -0.847020 -0.013728 -0.002550 -0.000630 -0.002757
# 1 -0.853042 -0.012358  0.001593 -0.000360 -0.000034
# 2 -0.855125 -0.012437 -0.000673 -0.001191  0.001017
# 3 -0.856231 -0.013161  0.000125  0.000985  0.002496
# 4 -0.853060 -0.013163 -0.000696  0.000232 -0.002425

# %%
from autokeras import StructuredDataRegressor
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split

# %%
# basic data preparation
X = x_scaled_transf.astype('float32')
y = output_var.astype('float32')

# %%
# separate into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (4244, 5) (1061, 5) (4244, 1) (1061, 1)

# %%
# Initialize the StructuredDataRegressor
reg = StructuredDataRegressor(max_trials=15,overwrite=True,metrics=['mae'])
# Search for the best model.
reg.fit(X_train.to_numpy(),y_train.to_numpy(), validation_split=0.2,epochs=100, verbose=0)
# Out:
# INFO:tensorflow:Oracle triggered exit
# Epoch 1/100
# 133/133 [==============================] - 2s 12ms/step - loss: 807321.6250 - mae: 668.5361
# Epoch 2/100
# 133/133 [==============================] - 2s 12ms/step - loss: 2483.9912 - mae: 33.1603
# Epoch 3/100
# 133/133 [==============================] - 2s 11ms/step - loss: 511.4877 - mae: 16.7824
# Epoch 4/100
# 133/133 [==============================] - 2s 12ms/step - loss: 211.5648 - mae: 10.8499
# Epoch 5/100
# 133/133 [==============================] - 2s 12ms/step - loss: 106.2427 - mae: 7.5438
# Epoch 6/100
# 133/133 [==============================] - 1s 11ms/step - loss: 62.1446 - mae: 5.5872
# Epoch 7/100
# 133/133 [==============================] - 2s 12ms/step - loss: 41.7067 - mae: 4.4190
# Epoch 8/100
# 133/133 [==============================] - 2s 11ms/step - loss: 31.3647 - mae: 3.7042
# Epoch 9/100
# 133/133 [==============================] - 1s 11ms/step - loss: 25.7355 - mae: 3.2662
# Epoch 10/100
# 133/133 [==============================] - 2s 12ms/step - loss: 22.5337 - mae: 2.9976
# Epoch 11/100
# 133/133 [==============================] - 1s 11ms/step - loss: 20.6303 - mae: 2.8371
# Epoch 12/100
# 133/133 [==============================] - 2s 11ms/step - loss: 19.4502 - mae: 2.7350
# Epoch 13/100
# 133/133 [==============================] - 2s 11ms/step - loss: 18.6931 - mae: 2.6685
# Epoch 14/100
# 133/133 [==============================] - 2s 11ms/step - loss: 18.1924 - mae: 2.6247
# Epoch 15/100
# 133/133 [==============================] - 2s 12ms/step - loss: 17.8554 - mae: 2.5958
# Epoch 16/100
# 133/133 [==============================] - 2s 12ms/step - loss: 17.6191 - mae: 2.5774
# Epoch 17/100
# 133/133 [==============================] - 2s 11ms/step - loss: 17.4483 - mae: 2.5661
# Epoch 18/100
# 133/133 [==============================] - 2s 12ms/step - loss: 17.3245 - mae: 2.5596
# Epoch 19/100
# 133/133 [==============================] - 2s 12ms/step - loss: 17.2349 - mae: 2.5571
# Epoch 20/100
# 133/133 [==============================] - 2s 12ms/step - loss: 17.1653 - mae: 2.5573
# Epoch 21/100
# 133/133 [==============================] - 2s 12ms/step - loss: 17.0995 - mae: 2.5598
# Epoch 22/100
# 133/133 [==============================] - 2s 12ms/step - loss: 17.0279 - mae: 2.5620
# Epoch 23/100
# 133/133 [==============================] - 2s 11ms/step - loss: 16.9525 - mae: 2.5627
# Epoch 24/100
# 133/133 [==============================] - 2s 11ms/step - loss: 16.8883 - mae: 2.5628
# Epoch 25/100
# 133/133 [==============================] - 2s 12ms/step - loss: 16.8453 - mae: 2.5646
# Epoch 26/100
# 133/133 [==============================] - 2s 12ms/step - loss: 16.8249 - mae: 2.5678
# Epoch 27/100
# 133/133 [==============================] - 2s 12ms/step - loss: 16.8273 - mae: 2.5722
# Epoch 28/100
# 133/133 [==============================] - 2s 12ms/step - loss: 16.8426 - mae: 2.5779
# Epoch 29/100
# 133/133 [==============================] - 1s 11ms/step - loss: 16.8820 - mae: 2.5854
# Epoch 30/100
# 133/133 [==============================] - 2s 12ms/step - loss: 16.9380 - mae: 2.5965
# Epoch 31/100
# 133/133 [==============================] - 2s 12ms/step - loss: 16.9890 - mae: 2.6087
# Epoch 32/100
# 133/133 [==============================] - 2s 12ms/step - loss: 16.9885 - mae: 2.6146
# Epoch 33/100
# 133/133 [==============================] - 2s 11ms/step - loss: 16.9250 - mae: 2.6108
# Epoch 34/100
# 133/133 [==============================] - 2s 13ms/step - loss: 16.8545 - mae: 2.6027
# Epoch 35/100
# 133/133 [==============================] - 2s 12ms/step - loss: 16.8338 - mae: 2.5979
# Epoch 36/100
# 133/133 [==============================] - 2s 11ms/step - loss: 16.8708 - mae: 2.5997
# Epoch 37/100
# 133/133 [==============================] - 2s 11ms/step - loss: 16.9820 - mae: 2.6093
# Epoch 38/100
# 133/133 [==============================] - 1s 11ms/step - loss: 17.1693 - mae: 2.6276
# Epoch 39/100
# 133/133 [==============================] - 2s 12ms/step - loss: 17.4560 - mae: 2.6591
# Epoch 40/100
# 133/133 [==============================] - 2s 12ms/step - loss: 17.8075 - mae: 2.7026
# Epoch 41/100
# 133/133 [==============================] - 2s 12ms/step - loss: 18.2308 - mae: 2.7621
# Epoch 42/100
# 133/133 [==============================] - 2s 12ms/step - loss: 18.6713 - mae: 2.8286
# Epoch 43/100
# 133/133 [==============================] - 2s 12ms/step - loss: 19.0063 - mae: 2.8765
# Epoch 44/100
# 133/133 [==============================] - 2s 12ms/step - loss: 19.1340 - mae: 2.8923
# Epoch 45/100
# 133/133 [==============================] - 2s 11ms/step - loss: 18.9982 - mae: 2.8748
# Epoch 46/100
# 133/133 [==============================] - 2s 12ms/step - loss: 18.8406 - mae: 2.8456
# Epoch 47/100
# 133/133 [==============================] - 2s 12ms/step - loss: 18.9020 - mae: 2.8369
# Epoch 48/100
# 133/133 [==============================] - 1s 11ms/step - loss: 19.0955 - mae: 2.8471
# Epoch 49/100
# 133/133 [==============================] - 2s 11ms/step - loss: 19.1167 - mae: 2.8445
# Epoch 50/100
# 133/133 [==============================] - 2s 12ms/step - loss: 18.9685 - mae: 2.8236
# Epoch 51/100
# 133/133 [==============================] - 2s 11ms/step - loss: 18.9729 - mae: 2.8239
# Epoch 52/100
# 133/133 [==============================] - 2s 12ms/step - loss: 19.1627 - mae: 2.8501
# Epoch 53/100
# 133/133 [==============================] - 2s 11ms/step - loss: 19.4564 - mae: 2.8825
# Epoch 54/100
# 133/133 [==============================] - 2s 12ms/step - loss: 19.6771 - mae: 2.9061
# Epoch 55/100
# 133/133 [==============================] - 2s 12ms/step - loss: 19.8630 - mae: 2.9259
# Epoch 56/100
# 133/133 [==============================] - 2s 12ms/step - loss: 20.0695 - mae: 2.9504
# Epoch 57/100
# 133/133 [==============================] - 2s 12ms/step - loss: 20.2231 - mae: 2.9700
# Epoch 58/100
# 133/133 [==============================] - 2s 12ms/step - loss: 20.2551 - mae: 2.9753
# Epoch 59/100
# 133/133 [==============================] - 2s 12ms/step - loss: 20.3228 - mae: 2.9860
# Epoch 60/100
# 133/133 [==============================] - 2s 11ms/step - loss: 20.3318 - mae: 2.9836
# Epoch 61/100
# 133/133 [==============================] - 2s 12ms/step - loss: 20.3925 - mae: 2.9899
# Epoch 62/100
# 133/133 [==============================] - 2s 12ms/step - loss: 20.4953 - mae: 2.9995
# Epoch 63/100
# 133/133 [==============================] - 2s 12ms/step - loss: 20.5974 - mae: 3.0113
# Epoch 64/100
# 133/133 [==============================] - 2s 12ms/step - loss: 20.7122 - mae: 3.0254
# Epoch 65/100
# 133/133 [==============================] - 2s 12ms/step - loss: 20.8407 - mae: 3.0402
# Epoch 66/100
# 133/133 [==============================] - 2s 12ms/step - loss: 20.9364 - mae: 3.0521
# Epoch 67/100
# 133/133 [==============================] - 2s 12ms/step - loss: 21.0208 - mae: 3.0623
# Epoch 68/100
# 133/133 [==============================] - 2s 12ms/step - loss: 21.0865 - mae: 3.0699
# Epoch 69/100
# 133/133 [==============================] - 2s 12ms/step - loss: 21.1181 - mae: 3.0746
# Epoch 70/100
# 133/133 [==============================] - 2s 12ms/step - loss: 21.1634 - mae: 3.0796
# Epoch 71/100
# 133/133 [==============================] - 1s 11ms/step - loss: 21.1699 - mae: 3.0815
# Epoch 72/100
# 133/133 [==============================] - 2s 11ms/step - loss: 21.1949 - mae: 3.0839
# Epoch 73/100
# 133/133 [==============================] - 2s 11ms/step - loss: 21.2019 - mae: 3.0852
# Epoch 74/100
# 133/133 [==============================] - 2s 12ms/step - loss: 21.2010 - mae: 3.0855
# Epoch 75/100
# 133/133 [==============================] - 2s 11ms/step - loss: 21.1955 - mae: 3.0856
# Epoch 76/100
# 133/133 [==============================] - 2s 11ms/step - loss: 21.2170 - mae: 3.0879
# Epoch 77/100
# 133/133 [==============================] - 1s 11ms/step - loss: 21.2105 - mae: 3.0872
# Epoch 78/100
# 133/133 [==============================] - 2s 11ms/step - loss: 21.1910 - mae: 3.0859
# Epoch 79/100
# 133/133 [==============================] - 2s 12ms/step - loss: 21.2095 - mae: 3.0880
# Epoch 80/100
# 133/133 [==============================] - 2s 12ms/step - loss: 21.2057 - mae: 3.0874
# Epoch 81/100
# 133/133 [==============================] - 2s 11ms/step - loss: 21.1869 - mae: 3.0860
# Epoch 82/100
# 133/133 [==============================] - 2s 12ms/step - loss: 21.1899 - mae: 3.0864
# Epoch 83/100
# 133/133 [==============================] - 2s 11ms/step - loss: 21.1948 - mae: 3.0869
# Epoch 84/100
# 133/133 [==============================] - 2s 12ms/step - loss: 21.1807 - mae: 3.0858
# Epoch 85/100
# 133/133 [==============================] - 2s 12ms/step - loss: 21.1806 - mae: 3.0860
# Epoch 86/100
# 133/133 [==============================] - 1s 11ms/step - loss: 21.1660 - mae: 3.0851
# Epoch 87/100
# 133/133 [==============================] - 1s 11ms/step - loss: 21.1760 - mae: 3.0860
# Epoch 88/100
# 133/133 [==============================] - 2s 12ms/step - loss: 21.1828 - mae: 3.0864
# Epoch 89/100
# 133/133 [==============================] - 2s 12ms/step - loss: 21.1576 - mae: 3.0847
# Epoch 90/100
# 133/133 [==============================] - 1s 11ms/step - loss: 21.1618 - mae: 3.0850
# Epoch 91/100
# 133/133 [==============================] - 2s 12ms/step - loss: 21.1599 - mae: 3.0849
# Epoch 92/100
# 133/133 [==============================] - 2s 11ms/step - loss: 21.1435 - mae: 3.0837
# Epoch 93/100
# 133/133 [==============================] - 2s 11ms/step - loss: 21.1499 - mae: 3.0843
# Epoch 94/100
# 133/133 [==============================] - 2s 12ms/step - loss: 21.1381 - mae: 3.0833
# Epoch 95/100
# 133/133 [==============================] - 2s 12ms/step - loss: 21.1426 - mae: 3.0838
# Epoch 96/100
# 133/133 [==============================] - 2s 11ms/step - loss: 21.1428 - mae: 3.0838
# Epoch 97/100
# 133/133 [==============================] - 2s 12ms/step - loss: 21.1278 - mae: 3.0826
# Epoch 98/100
# 133/133 [==============================] - 2s 12ms/step - loss: 21.1229 - mae: 3.0820
# Epoch 99/100
# 133/133 [==============================] - 2s 12ms/step - loss: 21.1078 - mae: 3.0806
# Epoch 100/100
# 133/133 [==============================] - 2s 12ms/step - loss: 21.1040 - mae: 3.0802
# INFO:tensorflow:Assets written to: ./structured_data_regressor/best_model/assets

# %%
predicted = reg.predict(X_test)
# Out:
# 34/34 [==============================] - 0s 4ms/step

# %%
# evaluate the model
loss, acc =reg.evaluate(X_train,y_train, verbose=0)
print('Accuracy: %.3f' % acc)
print('loss: %.3f' % loss)
# Out:
# Accuracy: 2.746
# loss: 18.271

# %% [markdown]
# **EVALUATE MODEL PERFORMANCE FOR AutoKeras**

# %% [markdown]
# **MEAN ABSOLUTE ERROR (MAE) FOR TEST DATA**

# %%
from sklearn.metrics import mean_absolute_error
print("MEAN ABSOLUTE ERROR (MAE) FOR TEST DATA IS")
np.round(mean_absolute_error(predicted,y_test),3)
# Out:
# MEAN ABSOLUTE ERROR (MAE) FOR TEST DATA IS
# 2.808

# %% [markdown]
# **MEAN SQUARE ERROR (MSE) FOR TEST DATA**

# %%
from sklearn.metrics import mean_squared_error
print("MEAN SQUARE ERROR (MSE) FOR TEST DATA IS")
mse=np.round(mean_squared_error(predicted,y_test),3)
mse
# Out:
# MEAN SQUARE ERROR (MSE) FOR TEST DATA IS
# 20.38

# %% [markdown]
# **ROOT MEAN SQUARE ERROR (MSE) FOR TEST DATA**

# %%
import math
math.sqrt(mse)
# Out:
# 4.51442124316801

# %% [markdown]
# **MEDIAN ABSOLUTE ERROR (MAE) FOR TEST DATA**

# %%
from sklearn.metrics import median_absolute_error
print("MEDIAN ABSOLUTE ERROR (MAE) FOR TEST DATA IS")
np.round(median_absolute_error(predicted,y_test),3)
# Out:
# MEDIAN ABSOLUTE ERROR (MAE) FOR TEST DATA IS
# 1.734

# %% [markdown]
# **Mean Absolute Percentage Error FOR TEST DATA**

# %%
print("MAPE FOR TEST DATA IS")
mape1 = np.mean(np.abs((y_test - predicted)/y_test))*100
np.round(mape1,3)
# Out:
# MAPE FOR TEST DATA IS
# Close    0.319
# dtype: float32

# %% [markdown]
# **Get the best performing model and Summarize the loaded model**

# %%
keras_model = reg.export_model()
keras_model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 5)]               0
#
#  multi_category_encoding (Mu  (None, 5)                0
#  ltiCategoryEncoding)
#
#  dense (Dense)               (None, 512)               3072
#
#  re_lu (ReLU)                (None, 512)               0
#
#  dense_1 (Dense)             (None, 1024)              525312
#
#  re_lu_1 (ReLU)              (None, 1024)              0
#
#  regression_head_1 (Dense)   (None, 1)                 1025
#
# =================================================================
# Total params: 529,409
# Trainable params: 529,409
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# **View the visual representation of the model**

# %%
import tensorflow as tf
tf.keras.utils.plot_model
plot_model(keras_model)

# %%
# !jupyter nbconvert StockMarketPrediction_PCA_LSTM_AutoKeras.ipynb
# Out:
# [NbConvertApp] Converting notebook StockMarketPrediction_PCA_LSTM_AutoKeras.ipynb to html
# [NbConvertApp] Writing 539581 bytes to StockMarketPrediction_PCA_LSTM_AutoKeras.html
