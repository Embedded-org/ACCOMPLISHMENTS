# %%
#Importing the Libraries
import matplotlib. pyplot as plt
import matplotlib
from sklearn.preprocessing import MinMaxScaler
import numpy as np
import pandas as pd
import sklearn
import sklearn.linear_model as lm
from sklearn import preprocessing
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.metrics import roc_curve,auc,recall_score,precision_score,accuracy_score,f1_score
from sklearn.metrics import confusion_matrix,average_precision_score,recall_score
import matplotlib.pyplot as plt
# %matplotlib inline
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
all_data = pd.read_csv("SBIBANK.csv")
all_data=all_data.drop(['Date','Trades','Deliverable Volume','%Deliverble','Symbol','Series'],axis=1)
all_data.head()
# Out:
#    Prev Close    Open    High     Low    Last   Close    VWAP   Volume  \
# 0      225.60  236.00  243.65  234.25  243.65  243.65  240.83  2373228
# 1      243.65  243.65  262.00  238.85  258.00  259.10  251.46  4495741
# 2      259.10  249.00  264.70  245.00  249.05  248.45  252.35  3434058
# 3      248.45  252.00  268.00  252.00  260.50  261.00  262.18  6658801
# 4      261.00  261.50  279.90  255.00  279.00  273.30  269.02  7873985
#
#        Turnover
# 0  5.715338e+13
# 1  1.130506e+14
# 2  8.666008e+13
# 3  1.745817e+14
# 4  2.118287e+14

# %%
Close_list = all_data['Close'].tolist()
total=len(Close_list);

# %%
j=0
j=0
D1=[]
D2=[]
D3=[]
D4=[]
D5=[]
D6=[]
D7=[]
D8=[]
DIFF=[]
PERCDIFF=[]
TARGET=[]
for i in range(0,total):
  D1.append(Close_list[j])
  D2.append(Close_list[j+1])
  D3.append(Close_list[j+2])
  D4.append(Close_list[j+3])
  D5.append(Close_list[j+4])
  D6.append(Close_list[j+5])
  D7.append(Close_list[j+6])
  D8.append(Close_list[j+7])
  diff=Close_list[j+7]-Close_list[j+6]
  DIFF.append(diff)
  percdiff=(diff*100)/Close_list[j+7]
  PERCDIFF.append(percdiff)
  if(percdiff>1.0):
    TARGET.append('pos')
  elif(percdiff<-1.0):
    TARGET.append('neg')
  else:
    TARGET.append('neu')
  j=j+1;
  if(j==total-7):
    break

# %%
df1=pd.DataFrame(D1)
df2=pd.DataFrame(D2)
df3=pd.DataFrame(D3)
df4=pd.DataFrame(D4)
df5=pd.DataFrame(D5)
df6=pd.DataFrame(D6)
df7=pd.DataFrame(D7)
df8=pd.DataFrame(D8)
df9=pd.DataFrame(DIFF)
df10=pd.DataFrame(PERCDIFF)
df11=pd.DataFrame(TARGET)
df=pd.DataFrame()
df['Close']=all_data['Close']
df['D1']=df1
df['D2']=df2
df['D3']=df3
df['D4']=df4
df['D5']=df5
df['D6']=df6
df['D7']=df7
df['D8']=df8
df['DIFF']=df9
df['PERCDIFF']=df10
df['TARGET']=df11
df.dropna(inplace=True)
df.head(10)
# Out:
#     Close      D1      D2      D3      D4      D5      D6      D7      D8  \
# 0  243.65  243.65  259.10  248.45  261.00  273.30  269.50  247.95  244.75
# 1  259.10  259.10  248.45  261.00  273.30  269.50  247.95  244.75  244.50
# 2  248.45  248.45  261.00  273.30  269.50  247.95  244.75  244.50  239.20
# 3  261.00  261.00  273.30  269.50  247.95  244.75  244.50  239.20  235.90
# 4  273.30  273.30  269.50  247.95  244.75  244.50  239.20  235.90  236.45
# 5  269.50  269.50  247.95  244.75  244.50  239.20  235.90  236.45  243.95
# 6  247.95  247.95  244.75  244.50  239.20  235.90  236.45  243.95  237.70
# 7  244.75  244.75  244.50  239.20  235.90  236.45  243.95  237.70  237.45
# 8  244.50  244.50  239.20  235.90  236.45  243.95  237.70  237.45  228.30
# 9  239.20  239.20  235.90  236.45  243.95  237.70  237.45  228.30  224.85
#
#    DIFF  PERCDIFF TARGET
# 0 -3.20 -1.307457    neg
# 1 -0.25 -0.102249    neu
# 2 -5.30 -2.215719    neg
# 3 -3.30 -1.398898    neg
# 4  0.55  0.232607    neu
# 5  7.50  3.074400    pos
# 6 -6.25 -2.629365    neg
# 7 -0.25 -0.105285    neu
# 8 -9.15 -4.007884    neg
# 9 -3.45 -1.534356    neg

# %%
features = ['D1','D2','D3','D4','D5','D6']
df1=df[features]
df1['TARGET']=df['TARGET']
df1.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#        D1      D2      D3      D4      D5      D6 TARGET
# 0  243.65  259.10  248.45  261.00  273.30  269.50    neg
# 1  259.10  248.45  261.00  273.30  269.50  247.95    neu
# 2  248.45  261.00  273.30  269.50  247.95  244.75    neg
# 3  261.00  273.30  269.50  247.95  244.75  244.50    neg
# 4  273.30  269.50  247.95  244.75  244.50  239.20    neu

# %%
df0=pd.DataFrame()
df0['TARGET']= np.where(df1['TARGET']=='pos','1',(np.where(df['TARGET']=='neg','-1','0')))

df0.head()
df0.groupby('TARGET').size()
# Out:
#   TARGET
# 0     -1
# 1      0
# 2     -1
# 3     -1
# 4      0
# TARGET
# -1    1584
# 0     2321
# 1     1665
# dtype: int64

# %% [markdown]
# #Explore the class distribution

# %%
sns.countplot(df0['TARGET'])
plt.xlabel('TARGET')
plt.title('Number of positive negative and neutral messages')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0.5, 0, 'TARGET')
# Text(0.5, 1.0, 'Number of positive negative and neutral messages')

# %%
#DUMMY CODING USING THE LOOP STRUCTURE
for col in df1.columns:
  if df1[col].dtype=='object':
    df1[col]=pd.Categorical(df1[col]).codes
df1.head(100)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
#         D1      D2      D3      D4      D5      D6  TARGET
# 0   243.65  259.10  248.45  261.00  273.30  269.50       0
# 1   259.10  248.45  261.00  273.30  269.50  247.95       1
# 2   248.45  261.00  273.30  269.50  247.95  244.75       0
# 3   261.00  273.30  269.50  247.95  244.75  244.50       0
# 4   273.30  269.50  247.95  244.75  244.50  239.20       1
# ..     ...     ...     ...     ...     ...     ...     ...
# 95  180.40  180.60  184.30  187.80  192.50  198.60       0
# 96  180.60  184.30  187.80  192.50  198.60  203.80       2
# 97  184.30  187.80  192.50  198.60  203.80  199.30       2
# 98  187.80  192.50  198.60  203.80  199.30  202.05       2
# 99  192.50  198.60  203.80  199.30  202.05  205.80       1
#
# [100 rows x 7 columns]

# %%
scaler = MinMaxScaler()
feature_transform = scaler.fit_transform(df1[features])
feature_transform= pd.DataFrame(columns=features, data=feature_transform)
feature_transform.head()
# Out:
#          D1        D2        D3        D4        D5        D6
# 0  0.030521  0.035135  0.031955  0.035703  0.039376  0.038241
# 1  0.035135  0.031955  0.035703  0.039376  0.038241  0.031805
# 2  0.031955  0.035703  0.039376  0.038241  0.031805  0.030850
# 3  0.035703  0.039376  0.038241  0.031805  0.030850  0.030775
# 4  0.039376  0.038241  0.031805  0.030850  0.030775  0.029192

# %%
x=feature_transform
x.head()
y=df1['TARGET']
y.head()
# Out:
#          D1        D2        D3        D4        D5        D6
# 0  0.030521  0.035135  0.031955  0.035703  0.039376  0.038241
# 1  0.035135  0.031955  0.035703  0.039376  0.038241  0.031805
# 2  0.031955  0.035703  0.039376  0.038241  0.031805  0.030850
# 3  0.035703  0.039376  0.038241  0.031805  0.030850  0.030775
# 4  0.039376  0.038241  0.031805  0.030850  0.030775  0.029192
# 0    0
# 1    1
# 2    0
# 3    0
# 4    1
# Name: TARGET, dtype: int8

# %%
#create test and train data 70% and 30% split
train_x,test_x,train_y,test_y=train_test_split(x,y,test_size=0.3)
train_x.shape
test_x.shape
train_x.shape
train_y.shape
# Out:
# (3899, 6)
# (1671, 6)
# (3899, 6)
# (3899,)

# %%
#BUILD A LOGISTIC REGRESSION MODEL
from sklearn.linear_model import LogisticRegression
log = lm.LogisticRegression(penalty='l2',fit_intercept=True,max_iter=500,solver='lbfgs',tol=1e-5,multi_class='ovr',class_weight = 'balanced')

# %%
log.fit(train_x,train_y)
# Out:
# LogisticRegression(class_weight='balanced', max_iter=500, multi_class='ovr',
#                    tol=1e-05)

# %%
#GENERATE MODEL DIAGNOSTICS
classes=log.predict(test_x)
print(classes.size)
# Out:
# 1671

# %%
print("positive cases in test data:",test_y[test_y==1].shape[0])
print("Negative cases in Test Data:",test_y[test_y==0].shape[0])
# Out:
# positive cases in test data: 694
# Negative cases in Test Data: 476

# %% [markdown]
# # **ACCURACY SCORE-LOGISTIC REGRESSION class_weight = 'balanced'**

# %%
#PRECISION AND RECALL
print("ACCUIRACY SCORE")
print(metrics.accuracy_score(test_y,classes))
# Out:
# ACCUIRACY SCORE
# 0.3770197486535009

# %%
#PRECISION RECALL MATRIX
print("precision/recall Metrics")
print(metrics.classification_report(test_y,classes))
# Out:
# precision/recall Metrics
#               precision    recall  f1-score   support
#
#            0       0.29      0.35      0.32       476
#            1       0.43      0.63      0.51       694
#            2       0.34      0.06      0.10       501
#
#     accuracy                           0.38      1671
#    macro avg       0.35      0.34      0.31      1671
# weighted avg       0.36      0.38      0.33      1671

# %%
#CONFUSION MATRIX
print("CONFUSION MATRIX")
cf=metrics.confusion_matrix(test_y,classes)
lbl1=["Predicted 0","Predicted 1","Predicted 2"]
lbl2=["True 0","True 1","True 2"]
sns.heatmap(cf,annot=True,cmap="Greens",fmt="d",xticklabels=lbl1,yticklabels=lbl2)
plt.show()
# Out:
# CONFUSION MATRIX

# %%
#BUILD A LOGISTIC REGRESSION MODEL
from sklearn.linear_model import LogisticRegression
log = lm.LogisticRegression(penalty='l2',fit_intercept=True,max_iter=500,solver='lbfgs',tol=1e-5,multi_class='ovr',class_weight=None)

# %%
log.fit(train_x,train_y)
# Out:
# LogisticRegression(max_iter=500, multi_class='ovr', tol=1e-05)

# %%
#GENERATE MODEL DIAGNOSTICS
classes=log.predict(test_x)
print(classes.size)
# Out:
# 1671

# %%
print("positive cases in test data:",test_y[test_y==1].shape[0])
print("Negative cases in Test Data:",test_y[test_y==0].shape[0])
# Out:
# positive cases in test data: 694
# Negative cases in Test Data: 476

# %% [markdown]
# # **ACCURACY SCORE-LOGISTIC REGRESSION class_weight=None**

# %%
#PRECISION AND RECALL
print("ACCUIRACY SCORE")
print(metrics.accuracy_score(test_y,classes))
# Out:
# ACCUIRACY SCORE
# 0.414721723518851

# %%
#PRECISION RECALL MATRIX
print("precision/recall Metrics")
print(metrics.classification_report(test_y,classes))
# Out:
# precision/recall Metrics
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       476
#            1       0.41      1.00      0.59       694
#            2       0.00      0.00      0.00       501
#
#     accuracy                           0.41      1671
#    macro avg       0.14      0.33      0.20      1671
# weighted avg       0.17      0.41      0.24      1671
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
#CONFUSION MATRIX
print("CONFUSION MATRIX")
cf=metrics.confusion_matrix(test_y,classes)
lbl1=["Predicted 0","Predicted 1","Predicted 2"]
lbl2=["True 0","True 1","True 2"]
sns.heatmap(cf,annot=True,cmap="Greens",fmt="d",xticklabels=lbl1,yticklabels=lbl2)
plt.show()
# Out:
# CONFUSION MATRIX

# %%
#FIND OUT PROBABLITY PF THE CLASSES AND PREDICTED CLASSES
predicted_prob=log.predict_proba(test_x)
predicted_prob_df=pd.DataFrame(predicted_prob)
predicted_classes_df=pd.DataFrame(classes)
predicted_df=pd.concat([predicted_prob_df,predicted_classes_df],axis=1)
predicted_df.columns=['prob_0','prob_1','prob_2','class']
predicted_df.sample(10)
# Out:
#         prob_0    prob_1    prob_2  class
# 185   0.304174  0.391908  0.303918      1
# 1251  0.277109  0.425557  0.297334      1
# 1609  0.274899  0.428674  0.296427      1
# 1030  0.274481  0.429502  0.296017      1
# 1256  0.297374  0.401077  0.301549      1
# 1286  0.310153  0.387873  0.301974      1
# 1646  0.295443  0.406789  0.297768      1
# 489   0.300475  0.397684  0.301840      1
# 1472  0.283444  0.418309  0.298247      1
# 453   0.278440  0.425670  0.295890      1

# %%
predicted_df.groupby('class').size()
# Out:
# class
# 1    1670
# 2       1
# dtype: int64

# %%
#APPLY NEW THRESHOLD FOR OPTIMIZING PRECISION AND RECALL
new_y_test=predicted_prob[:,1]>=0.35
print(metrics.classification_report(test_y,new_y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       476
#            1       0.42      1.00      0.59       694
#            2       0.00      0.00      0.00       501
#
#     accuracy                           0.42      1671
#    macro avg       0.14      0.33      0.20      1671
# weighted avg       0.17      0.42      0.24      1671
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# #**ACCURACY SCORE-LOGISTIC REGRESSION APPLYING NEW THRESHOLD FOR OPTIMIZING PRECISION AND RECALL**

# %%
#PRECISION AND RECALL
print("ACCUIRACY SCORE")
print(metrics.accuracy_score(test_y,new_y_test))
# Out:
# ACCUIRACY SCORE
# 0.4153201675643327

# %%
#PRECISION RECALL MATRIX
print("precision/recall Metrics")
print(metrics.classification_report(test_y,new_y_test))
# Out:
# precision/recall Metrics
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       476
#            1       0.42      1.00      0.59       694
#            2       0.00      0.00      0.00       501
#
#     accuracy                           0.42      1671
#    macro avg       0.14      0.33      0.20      1671
# weighted avg       0.17      0.42      0.24      1671
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
#CONFUSION MATRIX
print("CONFUSION MATRIX")
cf=metrics.confusion_matrix(test_y,new_y_test)
lbl1=["Predicted 0","Predicted 1","Predicted 2"]
lbl2=["True 0","True 1","True 2"]
sns.heatmap(cf,annot=True,cmap="Greens",fmt="d",xticklabels=lbl1,yticklabels=lbl2)
plt.show()
# Out:
# CONFUSION MATRIX

# %%
# !jupyter nbconvert SBIpercdiff_1_0_SMP_LR.ipynb
# Out:
# [NbConvertApp] Converting notebook SBIpercdiff_1_0_SMP_LR.ipynb to html
# [NbConvertApp] Writing 417873 bytes to SBIpercdiff_1_0_SMP_LR.html
