# %%
#Importing the Libraries

import matplotlib. pyplot as plt
import matplotlib
from sklearn.preprocessing import MinMaxScaler
import numpy as np
import pandas as pd
import sklearn
import sklearn.linear_model as lm
from sklearn import preprocessing
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.metrics import roc_curve,auc,recall_score,precision_score,accuracy_score,f1_score
from sklearn.metrics import confusion_matrix,average_precision_score,recall_score
import matplotlib.pyplot as plt
# %matplotlib inline
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
all_data = pd.read_csv("KOTAKBANK.csv")
all_data=all_data.drop(['Date','Trades','Deliverable Volume','%Deliverble','Symbol','Series'],axis=1)
all_data.head()
# Out:
#    Prev Close   Open    High     Low    Last   Close    VWAP  Volume  \
# 0      212.35  220.0  229.35  220.00  229.35  229.35  229.13    7086
# 1      229.35  247.7  247.70  225.25  247.70  246.95  244.12   73681
# 2      246.95  229.0  240.00  227.20  228.00  228.40  233.75  105799
# 3      228.40  235.1  239.00  217.00  224.95  225.90  226.84   40202
# 4      225.90  213.0  219.00  207.85  207.85  208.85  209.94   24463
#
#        Turnover
# 0  1.623640e+11
# 1  1.798729e+12
# 2  2.473093e+12
# 3  9.119546e+11
# 4  5.135747e+11

# %%
Close_list = all_data['Close'].tolist()
total=len(Close_list);

# %%
j=0
j=0
D1=[]
D2=[]
D3=[]
D4=[]
D5=[]
D6=[]
D7=[]
D8=[]
DIFF=[]
PERCDIFF=[]
TARGET=[]
for i in range(0,total):
  D1.append(Close_list[j])
  D2.append(Close_list[j+1])
  D3.append(Close_list[j+2])
  D4.append(Close_list[j+3])
  D5.append(Close_list[j+4])
  D6.append(Close_list[j+5])
  D7.append(Close_list[j+6])
  D8.append(Close_list[j+7])
  diff=Close_list[j+7]-Close_list[j+6]
  DIFF.append(diff)
  percdiff=(diff*100)/Close_list[j+7]
  PERCDIFF.append(percdiff)
  if(percdiff>1.5):
    TARGET.append('pos')
  elif(percdiff<-1.5):
    TARGET.append('neg')
  else:
    TARGET.append('neu')
  j=j+1;
  if(j==total-7):
    break

# %%
df1=pd.DataFrame(D1)
df2=pd.DataFrame(D2)
df3=pd.DataFrame(D3)
df4=pd.DataFrame(D4)
df5=pd.DataFrame(D5)
df6=pd.DataFrame(D6)
df7=pd.DataFrame(D7)
df8=pd.DataFrame(D8)
df9=pd.DataFrame(DIFF)
df10=pd.DataFrame(PERCDIFF)
df11=pd.DataFrame(TARGET)
df=pd.DataFrame()
df['Close']=all_data['Close']
df['D1']=df1
df['D2']=df2
df['D3']=df3
df['D4']=df4
df['D5']=df5
df['D6']=df6
df['D7']=df7
df['D8']=df8
df['DIFF']=df9
df['PERCDIFF']=df10
df['TARGET']=df11
df.dropna(inplace=True)
df.head(10)
# Out:
#     Close      D1      D2      D3      D4      D5      D6      D7      D8  \
# 0  229.35  229.35  246.95  228.40  225.90  208.85  192.15  176.80  162.70
# 1  246.95  246.95  228.40  225.90  208.85  192.15  176.80  162.70  167.35
# 2  228.40  228.40  225.90  208.85  192.15  176.80  162.70  167.35  159.85
# 3  225.90  225.90  208.85  192.15  176.80  162.70  167.35  159.85  153.50
# 4  208.85  208.85  192.15  176.80  162.70  167.35  159.85  153.50  149.50
# 5  192.15  192.15  176.80  162.70  167.35  159.85  153.50  149.50  161.50
# 6  176.80  176.80  162.70  167.35  159.85  153.50  149.50  161.50  174.45
# 7  162.70  162.70  167.35  159.85  153.50  149.50  161.50  174.45  188.45
# 8  167.35  167.35  159.85  153.50  149.50  161.50  174.45  188.45  203.55
# 9  159.85  159.85  153.50  149.50  161.50  174.45  188.45  203.55  200.60
#
#     DIFF  PERCDIFF TARGET
# 0 -14.10 -8.666257    neg
# 1   4.65  2.778608    pos
# 2  -7.50 -4.691899    neg
# 3  -6.35 -4.136808    neg
# 4  -4.00 -2.675585    neg
# 5  12.00  7.430341    pos
# 6  12.95  7.423330    pos
# 7  14.00  7.429026    pos
# 8  15.10  7.418325    pos
# 9  -2.95 -1.470588    neu

# %%
features = ['D1','D2','D3','D4','D5','D6']
df1=df[features]
df1['TARGET']=df['TARGET']
df1.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#        D1      D2      D3      D4      D5      D6 TARGET
# 0  229.35  246.95  228.40  225.90  208.85  192.15    neg
# 1  246.95  228.40  225.90  208.85  192.15  176.80    pos
# 2  228.40  225.90  208.85  192.15  176.80  162.70    neg
# 3  225.90  208.85  192.15  176.80  162.70  167.35    neg
# 4  208.85  192.15  176.80  162.70  167.35  159.85    neg

# %%
df0=pd.DataFrame()
df0['TARGET']= np.where(df1['TARGET']=='pos','1',(np.where(df['TARGET']=='neg','-1','0')))

df0.head()
df0.groupby('TARGET').size()
# Out:
#   TARGET
# 0     -1
# 1      1
# 2     -1
# 3     -1
# 4     -1
# TARGET
# -1    1046
# 0     3070
# 1     1133
# dtype: int64

# %% [markdown]
# #Explore the class distribution

# %%
sns.countplot(df0['TARGET'])
plt.xlabel('TARGET')
plt.title('Number of positive negative and neutral messages')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0.5, 0, 'TARGET')
# Text(0.5, 1.0, 'Number of positive negative and neutral messages')

# %%
#DUMMY CODING USING THE LOOP STRUCTURE
for col in df1.columns:
  if df1[col].dtype=='object':
    df1[col]=pd.Categorical(df1[col]).codes
df1.head(100)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
#         D1      D2      D3      D4      D5      D6  TARGET
# 0   229.35  246.95  228.40  225.90  208.85  192.15       0
# 1   246.95  228.40  225.90  208.85  192.15  176.80       2
# 2   228.40  225.90  208.85  192.15  176.80  162.70       0
# 3   225.90  208.85  192.15  176.80  162.70  167.35       0
# 4   208.85  192.15  176.80  162.70  167.35  159.85       0
# ..     ...     ...     ...     ...     ...     ...     ...
# 95   43.00   43.10   43.15   43.00   43.00   43.00       1
# 96   43.10   43.15   43.00   43.00   43.00   43.15       1
# 97   43.15   43.00   43.00   43.00   43.15   43.00       0
# 98   43.00   43.00   43.00   43.15   43.00   43.00       1
# 99   43.00   43.00   43.15   43.00   43.00   37.75       0
#
# [100 rows x 7 columns]

# %%
scaler = MinMaxScaler()
feature_transform = scaler.fit_transform(df1[features])
feature_transform= pd.DataFrame(columns=features, data=feature_transform)
feature_transform.head()
# Out:
#          D1        D2        D3        D4        D5        D6
# 0  0.092529  0.100588  0.092094  0.090949  0.083141  0.075493
# 1  0.100588  0.092094  0.090949  0.083141  0.075493  0.068463
# 2  0.092094  0.090949  0.083141  0.075493  0.068463  0.062006
# 3  0.090949  0.083141  0.075493  0.068463  0.062006  0.064136
# 4  0.083141  0.075493  0.068463  0.062006  0.064136  0.060701

# %%
x=feature_transform
x.head()
y=df1['TARGET']
y.head()
# Out:
#          D1        D2        D3        D4        D5        D6
# 0  0.092529  0.100588  0.092094  0.090949  0.083141  0.075493
# 1  0.100588  0.092094  0.090949  0.083141  0.075493  0.068463
# 2  0.092094  0.090949  0.083141  0.075493  0.068463  0.062006
# 3  0.090949  0.083141  0.075493  0.068463  0.062006  0.064136
# 4  0.083141  0.075493  0.068463  0.062006  0.064136  0.060701
# 0    0
# 1    2
# 2    0
# 3    0
# 4    0
# Name: TARGET, dtype: int8

# %%
#create test and train data 70% and 30% split
train_x,test_x,train_y,test_y=train_test_split(x,y,test_size=0.3)
train_x.shape
test_x.shape
train_x.shape
train_y.shape
# Out:
# (3674, 6)
# (1575, 6)
# (3674, 6)
# (3674,)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree
import pydotplus

#CREATE DECISION TREE CLASSIFIER OBJECT
decisiontree1=DecisionTreeClassifier(criterion="gini",random_state=0,max_depth=4,class_weight=None)
#TRAIN MODEL
model=decisiontree1.fit(train_x,train_y)
model
classes=decisiontree1.predict(test_x)
# Out:
# DecisionTreeClassifier(max_depth=4, random_state=0)

# %% [markdown]
# #ACCURACY SCORE-Decision Tree Classifier

# %%
#PRECISION AND RECALL
print("ACCUIRACY SCORE")
print(metrics.accuracy_score(test_y,classes))
# Out:
# ACCUIRACY SCORE
# 0.5904761904761905

# %%
#PRECISION RECALL MATRIX
print("precision/recall Metrics")
print(metrics.classification_report(test_y,classes))
# Out:
# precision/recall Metrics
#               precision    recall  f1-score   support
#
#            0       0.24      0.01      0.02       314
#            1       0.60      0.98      0.75       937
#            2       0.27      0.03      0.06       324
#
#     accuracy                           0.59      1575
#    macro avg       0.37      0.34      0.27      1575
# weighted avg       0.46      0.59      0.46      1575

# %%
#CONFUSION MATRIX
print("CONFUSION MATRIX")
cf=metrics.confusion_matrix(test_y,classes)
lbl1=["Predicted 0","Predicted 1","Predicted 2"]
lbl2=["True 0","True 1","True 2"]
sns.heatmap(cf,annot=True,cmap="Greens",fmt="d",xticklabels=lbl1,yticklabels=lbl2)
plt.show()
# Out:
# CONFUSION MATRIX

# %%
from scipy.stats import randint
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import RandomizedSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn import tree
from sklearn.model_selection import GridSearchCV

# %%
param_dist = {"max_depth": [3, None],
              "max_features": randint(1, 6),
              "min_samples_leaf": randint(1, 6),
              "criterion": ["gini", "entropy"]}

# %%
# Instantiate the RandomizedSearchCV object: tree_cv
tree_cv = RandomizedSearchCV(decisiontree1, param_dist, cv=5)

# %%
# Fit it to the data
tree_cv.fit(train_x,train_y)
# Print the tuned parameters and score
print("Tuned Decision Tree Parameters: {}".format(tree_cv.best_params_))
print("Best score is {}".format(tree_cv.best_score_))
classes=tree_cv.predict(test_x)
# Out:
# RandomizedSearchCV(cv=5,
#                    estimator=DecisionTreeClassifier(max_depth=4,
#                                                     random_state=0),
#                    param_distributions={'criterion': ['gini', 'entropy'],
#                                         'max_depth': [3, None],
#                                         'max_features': <scipy.stats._distn_infrastructure.rv_frozen object at 0x7f011156de50>,
#                                         'min_samples_leaf': <scipy.stats._distn_infrastructure.rv_frozen object at 0x7f011156df50>})
# Tuned Decision Tree Parameters: {'criterion': 'gini', 'max_depth': 3, 'max_features': 5, 'min_samples_leaf': 5}
# Best score is 0.5773007840738476

# %% [markdown]
# #ACCURACY SCORE-Decision Tree Classifier using RandomizedSearchCV

# %%
#PRECISION AND RECALL
print("ACCUIRACY SCORE")
print(metrics.accuracy_score(test_y,classes))
# Out:
# ACCUIRACY SCORE
# 0.5923809523809523

# %%
#PRECISION RECALL MATRIX
print("precision/recall Metrics")
print(metrics.classification_report(test_y,classes))
# Out:
# precision/recall Metrics
#               precision    recall  f1-score   support
#
#            0       0.29      0.01      0.01       314
#            1       0.60      0.98      0.75       937
#            2       0.29      0.04      0.07       324
#
#     accuracy                           0.59      1575
#    macro avg       0.39      0.34      0.28      1575
# weighted avg       0.47      0.59      0.46      1575

# %%
#CONFUSION MATRIX
print("CONFUSION MATRIX")
cf=metrics.confusion_matrix(test_y,classes)
lbl1=["Predicted 0","Predicted 1","Predicted 2"]
lbl2=["True 0","True 1","True 2"]
sns.heatmap(cf,annot=True,cmap="Greens",fmt="d",xticklabels=lbl1,yticklabels=lbl2)
plt.show()
# Out:
# CONFUSION MATRIX

# %%
my_max_depth=[2,5,10,15,20,25]
my_criterion=['gini','entropy']
#BUILDING THE MODEL
mytreeone=DecisionTreeClassifier()
#CROSS VALIDATION TELLS HOW A MODEL PERFORMS ON A DATASET USING MULTIPLE SAMPLES OF TRAIN DATA
grid=GridSearchCV(estimator=mytreeone,cv=3,param_grid=dict(max_depth=my_max_depth,criterion=my_criterion))
grid.fit(train_x,train_y)
classes=grid.predict(test_x)
# Out:
# GridSearchCV(cv=3, estimator=DecisionTreeClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [2, 5, 10, 15, 20, 25]})

# %% [markdown]
# #ACCURACY SCORE-Decision Tree Classifier using GridSearchCV

# %%
#PRECISION AND RECALL
print("ACCUIRACY SCORE")
print(metrics.accuracy_score(test_y,classes))
# Out:
# ACCUIRACY SCORE
# 0.5917460317460318

# %%
#PRECISION RECALL MATRIX
print("precision/recall Metrics")
print(metrics.classification_report(test_y,classes))
# Out:
# precision/recall Metrics
#               precision    recall  f1-score   support
#
#            0       0.14      0.01      0.01       314
#            1       0.60      0.99      0.74       937
#            2       0.00      0.00      0.00       324
#
#     accuracy                           0.59      1575
#    macro avg       0.25      0.33      0.25      1575
# weighted avg       0.38      0.59      0.45      1575
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
#CONFUSION MATRIX
print("CONFUSION MATRIX")
cf=metrics.confusion_matrix(test_y,classes)
lbl1=["Predicted 0","Predicted 1","Predicted 2"]
lbl2=["True 0","True 1","True 2"]
sns.heatmap(cf,annot=True,cmap="Greens",fmt="d",xticklabels=lbl1,yticklabels=lbl2)
plt.show()
# Out:
# CONFUSION MATRIX

# %%
n_estimators=[50,100,200,250]
criterion=['gini','entropy']
min_samples_split=[5,10,20,25,50]
max_depth=[25,30,35,40,None]

# %%
param_grid={'n_estimators':n_estimators,'criterion':criterion,'min_samples_split':min_samples_split,'max_depth':max_depth}
rf=RandomForestClassifier()
rf_g=RandomizedSearchCV(rf,param_grid,cv=5,verbose=2,n_jobs=1)
rf_g.fit(x,y)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV] END criterion=gini, max_depth=40, min_samples_split=20, n_estimators=100; total time=   1.3s
# [CV] END criterion=gini, max_depth=40, min_samples_split=20, n_estimators=100; total time=   1.1s
# [CV] END criterion=gini, max_depth=40, min_samples_split=20, n_estimators=100; total time=   1.0s
# [CV] END criterion=gini, max_depth=40, min_samples_split=20, n_estimators=100; total time=   1.1s
# [CV] END criterion=gini, max_depth=40, min_samples_split=20, n_estimators=100; total time=   1.2s
# [CV] END criterion=gini, max_depth=40, min_samples_split=5, n_estimators=50; total time=   0.7s
# [CV] END criterion=gini, max_depth=40, min_samples_split=5, n_estimators=50; total time=   0.6s
# [CV] END criterion=gini, max_depth=40, min_samples_split=5, n_estimators=50; total time=   0.6s
# [CV] END criterion=gini, max_depth=40, min_samples_split=5, n_estimators=50; total time=   0.6s
# [CV] END criterion=gini, max_depth=40, min_samples_split=5, n_estimators=50; total time=   0.9s
# [CV] END criterion=entropy, max_depth=30, min_samples_split=10, n_estimators=250; total time=   9.6s
# [CV] END criterion=entropy, max_depth=30, min_samples_split=10, n_estimators=250; total time=   5.6s
# [CV] END criterion=entropy, max_depth=30, min_samples_split=10, n_estimators=250; total time=   5.4s
# [CV] END criterion=entropy, max_depth=30, min_samples_split=10, n_estimators=250; total time=   5.9s
# [CV] END criterion=entropy, max_depth=30, min_samples_split=10, n_estimators=250; total time=   6.4s
# [CV] END criterion=gini, max_depth=40, min_samples_split=50, n_estimators=250; total time=   3.0s
# [CV] END criterion=gini, max_depth=40, min_samples_split=50, n_estimators=250; total time=   2.3s
# [CV] END criterion=gini, max_depth=40, min_samples_split=50, n_estimators=250; total time=   2.2s
# [CV] END criterion=gini, max_depth=40, min_samples_split=50, n_estimators=250; total time=   2.5s
# [CV] END criterion=gini, max_depth=40, min_samples_split=50, n_estimators=250; total time=   2.7s
# [CV] END criterion=gini, max_depth=30, min_samples_split=50, n_estimators=50; total time=   0.6s
# [CV] END criterion=gini, max_depth=30, min_samples_split=50, n_estimators=50; total time=   0.5s
# [CV] END criterion=gini, max_depth=30, min_samples_split=50, n_estimators=50; total time=   0.5s
# [CV] END criterion=gini, max_depth=30, min_samples_split=50, n_estimators=50; total time=   0.5s
# [CV] END criterion=gini, max_depth=30, min_samples_split=50, n_estimators=50; total time=   0.6s
# [CV] END criterion=entropy, max_depth=35, min_samples_split=10, n_estimators=50; total time=   1.4s
# [CV] END criterion=entropy, max_depth=35, min_samples_split=10, n_estimators=50; total time=   1.1s
# [CV] END criterion=entropy, max_depth=35, min_samples_split=10, n_estimators=50; total time=   1.1s
# [CV] END criterion=entropy, max_depth=35, min_samples_split=10, n_estimators=50; total time=   1.2s
# [CV] END criterion=entropy, max_depth=35, min_samples_split=10, n_estimators=50; total time=   1.2s
# [CV] END criterion=entropy, max_depth=30, min_samples_split=10, n_estimators=50; total time=   1.4s
# [CV] END criterion=entropy, max_depth=30, min_samples_split=10, n_estimators=50; total time=   1.1s
# [CV] END criterion=entropy, max_depth=30, min_samples_split=10, n_estimators=50; total time=   1.1s
# [CV] END criterion=entropy, max_depth=30, min_samples_split=10, n_estimators=50; total time=   1.2s
# [CV] END criterion=entropy, max_depth=30, min_samples_split=10, n_estimators=50; total time=   1.2s
# [CV] END criterion=gini, max_depth=35, min_samples_split=5, n_estimators=250; total time=   3.4s
# [CV] END criterion=gini, max_depth=35, min_samples_split=5, n_estimators=250; total time=   2.8s
# [CV] END criterion=gini, max_depth=35, min_samples_split=5, n_estimators=250; total time=   2.8s
# [CV] END criterion=gini, max_depth=35, min_samples_split=5, n_estimators=250; total time=   3.0s
# [CV] END criterion=gini, max_depth=35, min_samples_split=5, n_estimators=250; total time=   3.8s
# [CV] END criterion=gini, max_depth=None, min_samples_split=50, n_estimators=200; total time=   2.3s
# [CV] END criterion=gini, max_depth=None, min_samples_split=50, n_estimators=200; total time=   1.9s
# [CV] END criterion=gini, max_depth=None, min_samples_split=50, n_estimators=200; total time=   1.8s
# [CV] END criterion=gini, max_depth=None, min_samples_split=50, n_estimators=200; total time=   2.0s
# [CV] END criterion=gini, max_depth=None, min_samples_split=50, n_estimators=200; total time=   2.1s
# [CV] END criterion=gini, max_depth=35, min_samples_split=50, n_estimators=250; total time=   2.9s
# [CV] END criterion=gini, max_depth=35, min_samples_split=50, n_estimators=250; total time=   2.3s
# [CV] END criterion=gini, max_depth=35, min_samples_split=50, n_estimators=250; total time=   2.2s
# [CV] END criterion=gini, max_depth=35, min_samples_split=50, n_estimators=250; total time=   2.5s
# [CV] END criterion=gini, max_depth=35, min_samples_split=50, n_estimators=250; total time=   2.6s
# RandomizedSearchCV(cv=5, estimator=RandomForestClassifier(), n_jobs=1,
#                    param_distributions={'criterion': ['gini', 'entropy'],
#                                         'max_depth': [25, 30, 35, 40, None],
#                                         'min_samples_split': [5, 10, 20, 25,
#                                                               50],
#                                         'n_estimators': [50, 100, 200, 250]},
#                    verbose=2)

# %%
#PREDICT USING THE TRAINED MODEL
classes=rf_g.predict(test_x)

# %% [markdown]
# #ACCURACY SCORE-RandomForestClassifier using RandomizedSearchCV

# %%
#PRECISION AND RECALL
print("ACCUIRACY SCORE")
print(metrics.accuracy_score(test_y,classes))
# Out:
# ACCUIRACY SCORE
# 0.6660317460317461

# %%
#PRECISION RECALL MATRIX
print("precision/recall Metrics")
print(metrics.classification_report(test_y,classes))
# Out:
# precision/recall Metrics
#               precision    recall  f1-score   support
#
#            0       0.82      0.18      0.30       314
#            1       0.66      0.98      0.79       937
#            2       0.66      0.23      0.35       324
#
#     accuracy                           0.67      1575
#    macro avg       0.71      0.47      0.48      1575
# weighted avg       0.69      0.67      0.60      1575

# %%
#CONFUSION MATRIX
print("CONFUSION MATRIX")
cf=metrics.confusion_matrix(test_y,classes)
lbl1=["Predicted 0","Predicted 1","Predicted 2"]
lbl2=["True 0","True 1","True 2"]
sns.heatmap(cf,annot=True,cmap="Greens",fmt="d",xticklabels=lbl1,yticklabels=lbl2)
plt.show()
# Out:
# CONFUSION MATRIX

# %%
# !jupyter nbconvert KOTAKpercdiff_1_5_SMP_DT_RF.ipynb
# Out:
# [NbConvertApp] Converting notebook KOTAKpercdiff_1_5_SMP_DT_RF.ipynb to html
# [NbConvertApp] Writing 431802 bytes to KOTAKpercdiff_1_5_SMP_DT_RF.html
